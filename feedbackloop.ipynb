# %%
import pandas as pd

# %%
df=pd.read_csv('/content/corrected_kql_feedback.csv')

# %%
df = df.rename(columns={'corrected_generated_output': 'rejected', 'corrected_corrected_output': 'chosen'})

print(df)
# Out:
#                                          use_case  \
# 0                Identify logins from unknown IPs
# 1           Detect multiple failed login attempts
# 2         Track file access by unauthorized users
# 3                Monitor unusual network activity
# 4            Identify suspicious admin activities
# 5                Detect access to sensitive files
# 6             Monitor use of blacklisted software
# 7                Identify abnormal traffic spikes
# 8             Detect unauthorized database access
# 9            Monitor usage of privileged accounts
# 10        Identify devices with outdated software
# 11            Detect changes to security settings
# 12                 Monitor for malware signatures
# 13               Track access to critical systems
# 14       Identify logins during non-working hours
# 15  Detect unauthorized access to cloud resources
# 16              Monitor abnormal outbound traffic
# 17  Track failed login attempts on admin accounts
# ...

# %%
# !pip install -q torch accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.5.0
# !pip install -q sentencepiece

import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 87.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 40.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 55.6 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "ichrak550/llama-model-finetunned7"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# ...

# %%
df.to_json("dataset.json", orient="records", lines=True)

# %%
# !pip install huggingface_hub

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# ...

# %%
# Clonez le repository et ajoutez le fichier JSON
repo = Repository(repo_name, clone_from=repo_url)
repo.git_add("/content/my-dataset2/dataset.json")
repo.git_commit("Add dataset.json")
repo.git_push()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# /content/my-dataset2 is already a clone of https://huggingface.co/ichrak550/my-dataset2. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/my-dataset2 is already a clone of https://huggingface.co/ichrak550/my-dataset2. Make sure you pull the latest changes with `repo.git_pull()`.
# To https://huggingface.co/ichrak550/my-dataset2
#    9ef7e3d..7a60190  main -> main
#
# ...

# %%
from huggingface_hub import HfApi, HfFolder, Repository

# Authentifiez-vous
api = HfApi()
token = HfFolder.get_token()
username = api.whoami(token)["name"]

# Créez un nouveau dataset
repo_name = "my-dataset2"
repo_url = api.create_repo(repo_name, private=False, token=token)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/ichrak550/my-dataset2 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/ichrak550/my-dataset2 into local empty directory.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repository.py in git_add(self, pattern, auto_lfs_track)
#    1035         try:
# ...

# %%
from datasets import load_dataset


train_dataset = load_dataset("ichrak550/dataset", split="train")


print(train_dataset)
print("--chosen--")
print(train_dataset[4]["corrected_correct_output"])
print("--rejected--")
print(train_dataset[4]["rejected"])
# Out:
# ...
# Generating train split:   0%|          | 0/20 [00:00<?, ? examples/s]
# Dataset({
#     features: ['use_case', 'rejected', 'corrected_correct_output'],
#     num_rows: 20
# })
# --chosen--
# SecurityAlert | where AlertName == 'SuspiciousAdminActivity' | summarize by AdminAccount
# --rejected--
# AdminEvents | where ActivityType == 'Login' | summarize by Admin

# %%
def preprocess_function(examples):
    new_examples = {
        "input_ids_chosen": [],
        "attention_mask_chosen": [],
        "input_ids_rejected": [],
        "attention_mask_rejected": [],
    }
    for chosen, rejected in zip(examples["corrected_correct_output"], examples["rejected"]):
        tokenized_j = tokenizer(chosen, truncation=True)
        tokenized_k = tokenizer(rejected, truncation=True)

        new_examples["input_ids_chosen"].append(tokenized_j["input_ids"])
        new_examples["attention_mask_chosen"].append(tokenized_j["attention_mask"])
        new_examples["input_ids_rejected"].append(tokenized_k["input_ids"])
        new_examples["attention_mask_rejected"].append(tokenized_k["attention_mask"])

    return new_examples

# %%
train_dataset = train_dataset.map(
    preprocess_function,
    batched=True,
    num_proc=4,
)
train_dataset = train_dataset.filter(
    lambda x: len(x["input_ids_chosen"]) <= 512
    and len(x["input_ids_rejected"]) <= 512
)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=4):   0%|          | 0/20 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Filter:   0%|          | 0/20 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForSequenceClassification, BitsAndBytesConfig


quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)


model = AutoModelForSequenceClassification.from_pretrained(
    "ichrak550/llama-model-finetunned7",
    quantization_config=quantization_config,
    device_map={"": 0},
    trust_remote_code=True,
    num_labels=1,
)
model.config.use_cache = False
# Out:
# config.json:   0%|          | 0.00/630 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.88G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.89G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/7.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at ichrak550/llama-model-finetunned7 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments
from peft import LoraConfig
from trl import RewardTrainer


training_args = TrainingArguments(
    output_dir="./train_logs",
    max_steps=300,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    learning_rate=1.41e-5,
    optim="adamw_torch",
    save_steps=50,
    logging_steps=50,
    report_to="tensorboard",
    remove_unused_columns=False,
    num_train_epochs=10,
)


peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    bias="none",
    task_type="SEQ_CLS",
    modules_to_save=["scores"]
)


trainer = RewardTrainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    train_dataset=train_dataset,
    peft_config=peft_config,
    max_length=512,
)


trainer.train()
trainer.model.save_pretrained("./reward_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2411: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# ...

# %%
from peft import PeftModel

ft_model = PeftModel.from_pretrained(model, "./reward_model")

# %%
trainer.tokenizer.save_pretrained( "./reward_model")
# Out:
# ('./reward_model/tokenizer_config.json',
#  './reward_model/special_tokens_map.json',
#  './reward_model/tokenizer.model',
#  './reward_model/added_tokens.json',
#  './reward_model/tokenizer.json')

# %%
new_model = 'finalmodel'
ft_model.save_pretrained(new_model)

# %%
base_model = AutoModelForCausalLM.from_pretrained("ichrak550/llama-model-finetunned7")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]

# %%
peft_model = PeftModel.from_pretrained(base_model, new_model)
merged_model = peft_model.merge_and_unload()

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
merged_model.push_to_hub("ichrak550/llama-model-feedback")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py in working_or_temp_dir(working_dir, use_temp_dir)
#     455         with tempfile.TemporaryDirectory() as tmp_dir:
# --> 456             yield tmp_dir
#     457     else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in push_to_hub(self, repo_id, use_temp_dir, commit_message, private, use_auth_token, max_shard_size, create_pr, safe_serialization, **deprecated_kwargs)
#     813             # Save all files.
# --> 814             self.save_pretrained(work_dir, max_shard_size=max_shard_size, safe_serialization=safe_serialization)
#     815
#
# ...

# %%
trainer.tokenizer.push_to_hub("ichrak550/llama-model-feedback")
# Out:
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ichrak550/llama-model-feedback/commit/d94db4adceee8f93c5e7660f75ee348cd34fbadf', commit_message='Upload tokenizer', commit_description='', oid='d94db4adceee8f93c5e7660f75ee348cd34fbadf', pr_url=None, pr_revision=None, pr_num=None)
