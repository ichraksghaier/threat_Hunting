# %%
import os
import requests

def download_files_from_directory(directory_url, save_directory, headers=None):
    # Get the contents of the directory
    directory_contents = requests.get(directory_url, headers=headers).json()

    # Loop through each item in the directory contents
    for file_item in directory_contents:
        if file_item['type'] == 'file':
            # Download the file
            file_url = file_item['download_url']
            file_name = file_item['name']

            print(f"Downloading: {file_name}")

            response = requests.get(file_url, headers=headers)

            if response.status_code == 200:
                # Save the file
                with open(os.path.join(save_directory, file_name), 'wb') as file:
                    file.write(response.content)
                print(f"File saved to: {file_name}")
            else:
                print(f"Failed to download: {file_name}. Status code: {response.status_code}")
        elif file_item['type'] == 'dir':
            # Recursively download files from subdirectory
            subdir_url = file_item['url']
            subdir_name = file_item['name']
            subdir_save_directory = os.path.join(save_directory, subdir_name)

            print(f"Entering subdirectory: {subdir_name}")

            # Create subdirectory if it doesn't exist
            os.makedirs(subdir_save_directory, exist_ok=True)

            download_files_from_directory(subdir_url, subdir_save_directory, headers=headers)

            print(f"Exiting subdirectory: {subdir_name}")

# GitHub repository URL
repository_url = 'https://api.github.com/repos/Azure/Azure-Sentinel/contents/Hunting%20Queries/Microsoft%20365%20Defender'


headers = {'Authorization': 'Bearer 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'}

# Make a request to get the contents of the repository
response = requests.get(repository_url, headers=headers)

if response.status_code == 200:
    # Parse the JSON response
    contents = response.json()

    # Create a directory to save files
    save_directory = 'downloaded_files'
    os.makedirs(save_directory, exist_ok=True)

    # Loop through each item in the contents
    for item in contents:
        if item['type'] == 'file':
            # Download the file
            file_url = item['download_url']
            file_name = item['name']

            print(f"Downloading: {file_name}")

            response = requests.get(file_url, headers=headers)

            if response.status_code == 200:
                # Save the file
                with open(os.path.join(save_directory, file_name), 'wb') as file:
                    file.write(response.content)
                print(f"File saved to: {file_name}")
            else:
                print(f"Failed to download: {file_name}. Status code: {response.status_code}")
        elif item['type'] == 'dir':
            # Recursively download files from subdirectory
            subdir_url = item['url']
            subdir_name = item['name']
            subdir_save_directory = os.path.join(save_directory, subdir_name)

            print(f"Entering directory: {subdir_name}")

            # Create subdirectory if it doesn't exist
            os.makedirs(subdir_save_directory, exist_ok=True)

            download_files_from_directory(subdir_url, subdir_save_directory, headers=headers)

            print(f"Exiting directory: {subdir_name}")

else:
    print(f"Failed to access repository. Status code: {response.status_code}")
# Out:
# Entering directory: ASR rules
# Downloading: ASR-rules-categorized-detection-graph.yaml
# File saved to: ASR-rules-categorized-detection-graph.yaml
# Exiting directory: ASR rules
# Entering directory: Campaigns
# Downloading: APT Baby Shark.yaml
# File saved to: APT Baby Shark.yaml
# Downloading: APT29 thinktanks.yaml
# File saved to: APT29 thinktanks.yaml
# Downloading: Abuse.ch Recent Threat Feed (1).yaml
# File saved to: Abuse.ch Recent Threat Feed (1).yaml
# Downloading: Abuse.ch Recent Threat Feed.yaml
# File saved to: Abuse.ch Recent Threat Feed.yaml
# Downloading: Abusing settingcontent-ms.yaml
# File saved to: Abusing settingcontent-ms.yaml
# Entering subdirectory: Bazacall
# Downloading: Bazacall Emails.yaml
# File saved to: Bazacall Emails.yaml
# Downloading: Cobalt Strike Lateral Movement.yaml
# File saved to: Cobalt Strike Lateral Movement.yaml
# Downloading: Dropping payload via certutil.yaml
# File saved to: Dropping payload via certutil.yaml
# Downloading: Excel Macro Execution.yaml
# File saved to: Excel Macro Execution.yaml
# Downloading: Excel file download domain pattern.yaml
# File saved to: Excel file download domain pattern.yaml
# Downloading: Malicious Excel Delivery.yaml
# File saved to: Malicious Excel Delivery.yaml
# Downloading: NTDS theft.yaml
# File saved to: NTDS theft.yaml
# Downloading: Renamed Rclone Exfil.yaml
# File saved to: Renamed Rclone Exfil.yaml
# Downloading: RunDLL Suspicious Network Connection.yaml
# File saved to: RunDLL Suspicious Network Connection.yaml
# Exiting subdirectory: Bazacall
# Entering subdirectory: Bazarloader
# Downloading: Stolen Images Execution.yaml
# File saved to: Stolen Images Execution.yaml
# Downloading: Zip-Doc - Creation of JPG Payload File.yaml
# File saved to: Zip-Doc - Creation of JPG Payload File.yaml
# Downloading: Zip-Doc - Word Launching MSHTA.yaml
# File saved to: Zip-Doc - Word Launching MSHTA.yaml
# Exiting subdirectory: Bazarloader
# Downloading: Bear Activity GTR 2019.yaml
# File saved to: Bear Activity GTR 2019.yaml
# Downloading: Cloud Hopper.yaml
# File saved to: Cloud Hopper.yaml
# Downloading: DofoilNameCoinServerTraffic.yaml
# File saved to: DofoilNameCoinServerTraffic.yaml
# Downloading: Dopplepaymer In-Memory Malware Implant.yaml
# File saved to: Dopplepaymer In-Memory Malware Implant.yaml
# Downloading: Dragon Fly.yaml
# File saved to: Dragon Fly.yaml
# Entering subdirectory: EUROPIUM
# Downloading: Identify EUROPIUM IOCs.yaml
# File saved to: Identify EUROPIUM IOCs.yaml
# Downloading: Identify Microsoft Defender Antivirus detection related to EUROPIUM.yaml
# File saved to: Identify Microsoft Defender Antivirus detection related to EUROPIUM.yaml
# Downloading: Identify unusual identity additions related to EUROPIUM.yaml
# File saved to: Identify unusual identity additions related to EUROPIUM.yaml
# Exiting subdirectory: EUROPIUM
# Downloading: Elise backdoor.yaml
# File saved to: Elise backdoor.yaml
# Downloading: Equation Group C2 Communication.yaml
# File saved to: Equation Group C2 Communication.yaml
# Downloading: Hurricane Panda activity.yaml
# File saved to: Hurricane Panda activity.yaml
# Downloading: Judgement Panda exfil activity.yaml
# File saved to: Judgement Panda exfil activity.yaml
# Entering subdirectory: Jupyter-Solarmaker
# Downloading: deimos-component-execution.yaml
# File saved to: deimos-component-execution.yaml
# Downloading: evasive-powershell-executions.yaml
# File saved to: evasive-powershell-executions.yaml
# Downloading: evasive-powershell-strings.yaml
# File saved to: evasive-powershell-strings.yaml
# Downloading: successive-tk-domain-calls.yaml
# File saved to: successive-tk-domain-calls.yaml
# Exiting subdirectory: Jupyter-Solarmaker
# Entering subdirectory: KNOTWEED
# Downloading: KNOTWEED-AVDetections.yaml
# File saved to: KNOTWEED-AVDetections.yaml
# Downloading: KNOTWEED-COMRegistryKeyModifiedtoPointtoColorProfileFolder.yaml
# File saved to: KNOTWEED-COMRegistryKeyModifiedtoPointtoColorProfileFolder.yaml
# Downloading: KNOTWEED-DomainIOCsJuly2022.yaml
# File saved to: KNOTWEED-DomainIOCsJuly2022.yaml
# Downloading: KNOTWEED-DownloadingnewfileusingCurl.yaml
# File saved to: KNOTWEED-DownloadingnewfileusingCurl.yaml
# Downloading: KNOTWEED-FileHashIOCsJuly2022.yaml
# File saved to: KNOTWEED-FileHashIOCsJuly2022.yaml
# Downloading: KNOTWEED-PEFileDroppedinColorProfileFolder.yaml
# File saved to: KNOTWEED-PEFileDroppedinColorProfileFolder.yaml
# Exiting subdirectory: KNOTWEED
# Entering subdirectory: LemonDuck
# Downloading: LemonDuck-competition-killer.yaml
# File saved to: LemonDuck-competition-killer.yaml
# Downloading: LemonDuck-component-download-structure.yaml
# File saved to: LemonDuck-component-download-structure.yaml
# Downloading: LemonDuck-component-names.yaml
# File saved to: LemonDuck-component-names.yaml
# Downloading: LemonDuck-control-structure.yaml
# File saved to: LemonDuck-control-structure.yaml
# Downloading: LemonDuck-defender-exclusions.yaml
# File saved to: LemonDuck-defender-exclusions.yaml
# Downloading: LemonDuck-email-subjects.yaml
# File saved to: LemonDuck-email-subjects.yaml
# Downloading: LemonDuck-id-generation.yaml
# File saved to: LemonDuck-id-generation.yaml
# Downloading: LemonDuck-registration-function.yaml
# File saved to: LemonDuck-registration-function.yaml
# Exiting subdirectory: LemonDuck
# Entering subdirectory: Log4J
# Downloading: Alerts related to Log4j vulnerability.yaml
# File saved to: Alerts related to Log4j vulnerability.yaml
# Downloading: Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# File saved to: Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# Downloading: Suspicious JScript staging comment.yaml
# File saved to: Suspicious JScript staging comment.yaml
# Downloading: Suspicious PowerShell curl flags.yaml
# File saved to: Suspicious PowerShell curl flags.yaml
# Downloading: Suspicious process event creation from VMWare Horizon TomcatService.yaml
# File saved to: Suspicious process event creation from VMWare Horizon TomcatService.yaml
# Exiting subdirectory: Log4J
# Downloading: MacOceanLotusBackdoor.yaml
# File saved to: MacOceanLotusBackdoor.yaml
# Downloading: MacOceanLotusDropper.yaml
# File saved to: MacOceanLotusDropper.yaml
# Entering subdirectory: Macaw Ransomware
# Downloading: Disable Controlled Folders.yaml
# File saved to: Disable Controlled Folders.yaml
# Downloading: Imminent Ransomware.yaml
# File saved to: Imminent Ransomware.yaml
# Downloading: Inhibit recovery by disabling tools and functionality.yaml
# File saved to: Inhibit recovery by disabling tools and functionality.yaml
# Downloading: Mass account password change.yaml
# File saved to: Mass account password change.yaml
# Downloading: PSExec Attrib commands.yaml
# File saved to: PSExec Attrib commands.yaml
# Downloading: Use of MSBuild as LOLBin.yaml
# File saved to: Use of MSBuild as LOLBin.yaml
# Exiting subdirectory: Macaw Ransomware
# Downloading: OceanLotus registry activity.yaml
# File saved to: OceanLotus registry activity.yaml
# Entering subdirectory: Qakbot
# Downloading: Excel launching anomalous processes.yaml
# File saved to: Excel launching anomalous processes.yaml
# Downloading: General attempts to access local email store.yaml
# File saved to: General attempts to access local email store.yaml
# Downloading: Qakbot Craigslist Domains.yaml
# File saved to: Qakbot Craigslist Domains.yaml
# Downloading: Qakbot email theft (1).yaml
# File saved to: Qakbot email theft (1).yaml
# Downloading: Qakbot email theft.yaml
# File saved to: Qakbot email theft.yaml
# Downloading: Qakbot reconnaissance activities.yaml
# File saved to: Qakbot reconnaissance activities.yaml
# Exiting subdirectory: Qakbot
# Downloading: Ransomware hits healthcare - Alternate Data Streams use.yaml
# File saved to: Ransomware hits healthcare - Alternate Data Streams use.yaml
# Downloading: Ransomware hits healthcare - Backup deletion.yaml
# File saved to: Ransomware hits healthcare - Backup deletion.yaml
# Downloading: Ransomware hits healthcare - Cipher.exe tool deleting data.yaml
# File saved to: Ransomware hits healthcare - Cipher.exe tool deleting data.yaml
# Downloading: Ransomware hits healthcare - Clearing of system logs.yaml
# File saved to: Ransomware hits healthcare - Clearing of system logs.yaml
# Downloading: Ransomware hits healthcare - Possible compromised accounts.yaml
# File saved to: Ransomware hits healthcare - Possible compromised accounts.yaml
# Downloading: Ransomware hits healthcare - Robbinhood activity.yaml
# File saved to: Ransomware hits healthcare - Robbinhood activity.yaml
# Downloading: Ransomware hits healthcare - Turning off System Restore.yaml
# File saved to: Ransomware hits healthcare - Turning off System Restore.yaml
# Downloading: Ransomware hits healthcare - Vulnerable Gigabyte drivers.yaml
# File saved to: Ransomware hits healthcare - Vulnerable Gigabyte drivers.yaml
# Downloading: StarBlizzardDomainIOCsAug2022.yaml
# File saved to: StarBlizzardDomainIOCsAug2022.yaml
# Entering subdirectory: StrRAT malware
# Downloading: StrRAT-AV-Discovery.yaml
# File saved to: StrRAT-AV-Discovery.yaml
# Downloading: StrRAT-Email-Delivery.yaml
# File saved to: StrRAT-Email-Delivery.yaml
# Downloading: StrRAT-Malware-Persistence.yaml
# File saved to: StrRAT-Malware-Persistence.yaml
# Exiting subdirectory: StrRAT malware
# Entering subdirectory: Sysrv-botnet
# Downloading: app-armor-stopped.yaml
# File saved to: app-armor-stopped.yaml
# Downloading: java-executing-cmd-to-run-powershell.yaml
# File saved to: java-executing-cmd-to-run-powershell.yaml
# Downloading: kinsing-miner-download.yaml
# File saved to: kinsing-miner-download.yaml
# Downloading: oracle-webLogic-executing-powershell.yaml
# File saved to: oracle-webLogic-executing-powershell.yaml
# Downloading: rce-on-vulnerable-server.yaml
# File saved to: rce-on-vulnerable-server.yaml
# Downloading: tomcat-8-executing-powershell.yaml
# File saved to: tomcat-8-executing-powershell.yaml
# Exiting subdirectory: Sysrv-botnet
# Downloading: Threat actor Phosphorus masquerading as conference organizers (1).yaml
# File saved to: Threat actor Phosphorus masquerading as conference organizers (1).yaml
# Downloading: Threat actor Phosphorus masquerading as conference organizers (2).yaml
# File saved to: Threat actor Phosphorus masquerading as conference organizers (2).yaml
# Downloading: Threat actor Phosphorus masquerading as conference organizers.yaml
# File saved to: Threat actor Phosphorus masquerading as conference organizers.yaml
# Downloading: WastedLocker Downloader.yaml
# File saved to: WastedLocker Downloader.yaml
# Entering subdirectory: ZLoader
# Downloading: Malicious bat file.yaml
# File saved to: Malicious bat file.yaml
# Downloading: Payload Delivery.yaml
# File saved to: Payload Delivery.yaml
# Downloading: Suspicious Registry Keys.yaml
# File saved to: Suspicious Registry Keys.yaml
# Exiting subdirectory: ZLoader
# Downloading: apt sofacy zebrocy.yaml
# File saved to: apt sofacy zebrocy.yaml
# Downloading: apt sofacy.yaml
# File saved to: apt sofacy.yaml
# Downloading: apt ta17 293a ps.yaml
# File saved to: apt ta17 293a ps.yaml
# Downloading: apt tropictrooper.yaml
# File saved to: apt tropictrooper.yaml
# Downloading: apt unidentified nov 18 (1).yaml
# File saved to: apt unidentified nov 18 (1).yaml
# Downloading: apt unidentified nov 18.yaml
# File saved to: apt unidentified nov 18.yaml
# Downloading: c2-lookup-from-nonbrowser[Nobelium] (1).yaml
# File saved to: c2-lookup-from-nonbrowser[Nobelium] (1).yaml
# Downloading: c2-lookup-from-nonbrowser[Nobelium].yaml
# File saved to: c2-lookup-from-nonbrowser[Nobelium].yaml
# Downloading: c2-lookup-response[Nobelium] (1).yaml
# File saved to: c2-lookup-response[Nobelium] (1).yaml
# Downloading: c2-lookup-response[Nobelium].yaml
# File saved to: c2-lookup-response[Nobelium].yaml
# Downloading: cobalt-strike-invoked-w-wmi.yaml
# File saved to: cobalt-strike-invoked-w-wmi.yaml
# Downloading: compromised nvidia certificates[Lapsus$].yaml
# File saved to: compromised nvidia certificates[Lapsus$].yaml
# Downloading: compromised-certificate[Nobelium].yaml
# File saved to: compromised-certificate[Nobelium].yaml
# Downloading: confluence-weblogic-targeted.yaml
# File saved to: confluence-weblogic-targeted.yaml
# Downloading: cypherpunk-exclusive-commands.yaml
# File saved to: cypherpunk-exclusive-commands.yaml
# Downloading: cypherpunk-remote-exec-w-psexesvc.yaml
# File saved to: cypherpunk-remote-exec-w-psexesvc.yaml
# Downloading: detect-cyzfc-activity (1).yaml
# File saved to: detect-cyzfc-activity (1).yaml
# Downloading: detect-cyzfc-activity (2).yaml
# File saved to: detect-cyzfc-activity (2).yaml
# Downloading: detect-cyzfc-activity (3).yaml
# File saved to: detect-cyzfc-activity (3).yaml
# Downloading: detect-cyzfc-activity (4).yaml
# File saved to: detect-cyzfc-activity (4).yaml
# Downloading: detect-cyzfc-activity.yaml
# File saved to: detect-cyzfc-activity.yaml
# Downloading: fireeye-red-team-tools-CVEs [Nobelium].yaml
# File saved to: fireeye-red-team-tools-CVEs [Nobelium].yaml
# Downloading: fireeye-red-team-tools-HASHs [Nobelium].yaml
# File saved to: fireeye-red-team-tools-HASHs [Nobelium].yaml
# Downloading: known-affected-software-orion[Nobelium].yaml
# File saved to: known-affected-software-orion[Nobelium].yaml
# Downloading: launching-base64-powershell[Nobelium].yaml
# File saved to: launching-base64-powershell[Nobelium].yaml
# Downloading: launching-cmd-echo[Nobelium].yaml
# File saved to: launching-cmd-echo[Nobelium].yaml
# Downloading: locate-dll-created-locally[Nobelium].yaml
# File saved to: locate-dll-created-locally[Nobelium].yaml
# Downloading: locate-dll-loaded-in-memory[Nobelium].yaml
# File saved to: locate-dll-loaded-in-memory[Nobelium].yaml
# Downloading: oceanlotus-apt32-files.yaml
# File saved to: oceanlotus-apt32-files.yaml
# Downloading: oceanlotus-apt32-network.yaml
# File saved to: oceanlotus-apt32-network.yaml
# Downloading: possible-affected-software-orion[Nobelium].yaml
# File saved to: possible-affected-software-orion[Nobelium].yaml
# Downloading: redmenshen-bpfdoor-backdoor.yaml
# File saved to: redmenshen-bpfdoor-backdoor.yaml
# Downloading: robbinhood-driver.yaml
# File saved to: robbinhood-driver.yaml
# Downloading: robbinhood-evasion.yaml
# File saved to: robbinhood-evasion.yaml
# Downloading: snip3-aviation-targeting-emails.yaml
# File saved to: snip3-aviation-targeting-emails.yaml
# Downloading: snip3-detectsanboxie-function-call.yaml
# File saved to: snip3-detectsanboxie-function-call.yaml
# Downloading: snip3-encoded-powershell-structure.yaml
# File saved to: snip3-encoded-powershell-structure.yaml
# Downloading: snip3-malicious-network-connectivity.yaml
# File saved to: snip3-malicious-network-connectivity.yaml
# Downloading: snip3-revengerat-c2-exfiltration.yaml
# File saved to: snip3-revengerat-c2-exfiltration.yaml
# Exiting directory: Campaigns
# Entering directory: Cloud Apps
# Downloading: aad-group-adds.yaml
# File saved to: aad-group-adds.yaml
# Downloading: aad-role-adds.yaml
# File saved to: aad-role-adds.yaml
# Downloading: file-download-events.yaml
# File saved to: file-download-events.yaml
# Downloading: mass-downloads.yaml
# File saved to: mass-downloads.yaml
# Exiting directory: Cloud Apps
# Entering directory: Collection
# Downloading: Anomaly of MailItemAccess by Other Users Mailbox [Nobelium].yaml
# File saved to: Anomaly of MailItemAccess by Other Users Mailbox [Nobelium].yaml
# Downloading: HostExportingMailboxAndRemovingExport[Solarigate].yaml
# File saved to: HostExportingMailboxAndRemovingExport[Solarigate].yaml
# Downloading: MailItemsAccessedTimeSeries[Solarigate].yaml
# File saved to: MailItemsAccessedTimeSeries[Solarigate].yaml
# Exiting directory: Collection
# Entering directory: Command and Control
# Downloading: C2-NamedPipe.yaml
# File saved to: C2-NamedPipe.yaml
# Downloading: Connection to Rare DNS Hosts.yaml
# File saved to: Connection to Rare DNS Hosts.yaml
# Downloading: DNSPattern [Nobelium].yaml
# File saved to: DNSPattern [Nobelium].yaml
# Downloading: Device network events w low count FQDN.yaml
# File saved to: Device network events w low count FQDN.yaml
# Downloading: EncodedDomainURL [Nobelium].yaml
# File saved to: EncodedDomainURL [Nobelium].yaml
# Downloading: Tor.yaml
# File saved to: Tor.yaml
# Downloading: c2-bluekeep.yaml
# File saved to: c2-bluekeep.yaml
# Downloading: check-for-shadowhammer-activity-download-domain.yaml
# File saved to: check-for-shadowhammer-activity-download-domain.yaml
# Downloading: python-use-by-ransomware-macos.yaml
# File saved to: python-use-by-ransomware-macos.yaml
# Downloading: recon-with-rundll.yaml
# File saved to: recon-with-rundll.yaml
# Downloading: reverse-shell-ransomware-macos.yaml
# File saved to: reverse-shell-ransomware-macos.yaml
# Exiting directory: Command and Control
# Entering directory: Credential Access
# Downloading: Active Directory Sensitive Group Modifications.yaml
# File saved to: Active Directory Sensitive Group Modifications.yaml
# Downloading: Private Key Files.yaml
# File saved to: Private Key Files.yaml
# Downloading: cobalt-strike.yaml
# File saved to: cobalt-strike.yaml
# Downloading: doppelpaymer-procdump.yaml
# File saved to: doppelpaymer-procdump.yaml
# Downloading: identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# File saved to: identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# Downloading: lazagne.yaml
# File saved to: lazagne.yaml
# Downloading: logon-attempts-after-malicious-email.yaml
# File saved to: logon-attempts-after-malicious-email.yaml
# Downloading: procdump-lsass-credentials.yaml
# File saved to: procdump-lsass-credentials.yaml
# Downloading: wadhrama-credential-dump.yaml
# File saved to: wadhrama-credential-dump.yaml
# Downloading: wdigest-caching.yaml
# File saved to: wdigest-caching.yaml
# Exiting directory: Credential Access
# Entering directory: Defense evasion
# Downloading: ADFSDomainTrustMods[Nobelium].yaml
# File saved to: ADFSDomainTrustMods[Nobelium].yaml
# Downloading: Discovering potentially tampered devices [Nobelium].yaml
# File saved to: Discovering potentially tampered devices [Nobelium].yaml
# Downloading: MailPermissionsAddedToApplication[Nobelium].yaml
# File saved to: MailPermissionsAddedToApplication[Nobelium].yaml
# Downloading: PotentialMicrosoftDefenderTampering[Solarigate].yaml
# File saved to: PotentialMicrosoftDefenderTampering[Solarigate].yaml
# Downloading: UpdateStsRefreshToken[Solorigate].yaml
# File saved to: UpdateStsRefreshToken[Solorigate].yaml
# Downloading: alt-data-streams.yaml
# File saved to: alt-data-streams.yaml
# Downloading: clear-system-logs.yaml
# File saved to: clear-system-logs.yaml
# Downloading: deleting-data-w-cipher-tool.yaml
# File saved to: deleting-data-w-cipher-tool.yaml
# Downloading: doppelpaymer-stop-services.yaml
# File saved to: doppelpaymer-stop-services.yaml
# Downloading: hiding-java-class-file.yaml
# File saved to: hiding-java-class-file.yaml
# Downloading: locate-files-possibly-signed-by-fraudulent-ecc-certificates.yaml
# File saved to: locate-files-possibly-signed-by-fraudulent-ecc-certificates.yaml
# Downloading: qakbot-campaign-process-injection.yaml
# File saved to: qakbot-campaign-process-injection.yaml
# Downloading: qakbot-campaign-self-deletion.yaml
# File saved to: qakbot-campaign-self-deletion.yaml
# Downloading: regsvr32-rundll32-image-loads-abnormal-extension.yaml
# File saved to: regsvr32-rundll32-image-loads-abnormal-extension.yaml
# Downloading: regsvr32-rundll32-image-loads-from-abnormal-locations.yaml
# File saved to: regsvr32-rundll32-image-loads-from-abnormal-locations.yaml
# Downloading: regsvr32-rundll32-with-anomalous-parent-process.yaml
# File saved to: regsvr32-rundll32-with-anomalous-parent-process.yaml
# Exiting directory: Defense evasion
# Entering directory: Delivery
# Downloading: Doc attachment with link to download.yaml
# File saved to: Doc attachment with link to download.yaml
# Downloading: Dropbox downloads linked from other site.yaml
# File saved to: Dropbox downloads linked from other site.yaml
# Downloading: Email link + download + SmartScreen warning.yaml
# File saved to: Email link + download + SmartScreen warning.yaml
# Downloading: Gootkit-malware.yaml
# File saved to: Gootkit-malware.yaml
# Downloading: Open email link.yaml
# File saved to: Open email link.yaml
# Downloading: Pivot from detections to related downloads.yaml
# File saved to: Pivot from detections to related downloads.yaml
# Downloading: Qakbot Craigslist Domains.yaml
# File saved to: Qakbot Craigslist Domains.yaml
# Downloading: detect-jscript-file-creation.yaml
# File saved to: detect-jscript-file-creation.yaml
# Downloading: powercat-download.yaml
# File saved to: powercat-download.yaml
# Exiting directory: Delivery
# Entering directory: Device Inventory
# Downloading: Anomalous Device Models.yaml
# File saved to: Anomalous Device Models.yaml
# Downloading: Can Be Onboarded Devices.yaml
# File saved to: Can Be Onboarded Devices.yaml
# Downloading: Commonality of Operating Systems.yaml
# File saved to: Commonality of Operating Systems.yaml
# Downloading: Count and Percentage of DeviceType.yaml
# File saved to: Count and Percentage of DeviceType.yaml
# Downloading: Devices By Specific DeviceType and DeviceSubtype.yaml
# File saved to: Devices By Specific DeviceType and DeviceSubtype.yaml
# Downloading: Devices In Subnet - IPAddressV4.yaml
# File saved to: Devices In Subnet - IPAddressV4.yaml
# Downloading: Devices In Subnet - IPAddressV6.yaml
# File saved to: Devices In Subnet - IPAddressV6.yaml
# Downloading: Find Software By Name and Version.yaml
# File saved to: Find Software By Name and Version.yaml
# Downloading: Most Common Services.yaml
# File saved to: Most Common Services.yaml
# Downloading: NotOnboarded Devices by DeviceName Prefix.yaml
# File saved to: NotOnboarded Devices by DeviceName Prefix.yaml
# Downloading: NotOnboarded Devices by DeviceName Suffix.yaml
# File saved to: NotOnboarded Devices by DeviceName Suffix.yaml
# Downloading: Seen Connected Networks.yaml
# File saved to: Seen Connected Networks.yaml
# Downloading: Seen IPv4 Network Subnets.yaml
# File saved to: Seen IPv4 Network Subnets.yaml
# Downloading: Seen IPv6 Network Subnets.yaml
# File saved to: Seen IPv6 Network Subnets.yaml
# Exiting directory: Device Inventory
# Entering directory: Discovery
# Downloading: ConnectedNetworkDeviceDiscovery.yaml
# File saved to: ConnectedNetworkDeviceDiscovery.yaml
# Downloading: Detect-Not-Active-AD-User-Accounts.yaml
# File saved to: Detect-Not-Active-AD-User-Accounts.yaml
# Downloading: DetectTorRelayConnectivity.yaml
# File saved to: DetectTorRelayConnectivity.yaml
# Downloading: DetectTorrentUse.yaml
# File saved to: DetectTorrentUse.yaml
# Downloading: Discover hosts doing possible network scans.yaml
# File saved to: Discover hosts doing possible network scans.yaml
# Downloading: Enumeration of users & groups for lateral movement.yaml
# File saved to: Enumeration of users & groups for lateral movement.yaml
# Downloading: MultipleLdaps.yaml
# File saved to: MultipleLdaps.yaml
# Downloading: MultipleSensitiveLdaps.yaml
# File saved to: MultipleSensitiveLdaps.yaml
# Downloading: PasswordSearch.yaml
# File saved to: PasswordSearch.yaml
# Downloading: Roasting.yaml
# File saved to: Roasting.yaml
# Downloading: SMB shares discovery.yaml
# File saved to: SMB shares discovery.yaml
# Downloading: SensitiveLdaps.yaml
# File saved to: SensitiveLdaps.yaml
# Downloading: SuspiciousEnumerationUsingAdfind[Nobelium].yaml
# File saved to: SuspiciousEnumerationUsingAdfind[Nobelium].yaml
# Downloading: URL Detection.yaml
# File saved to: URL Detection.yaml
# Downloading: VulnComputers.yaml
# File saved to: VulnComputers.yaml
# Downloading: detect-nbtscan-activity.yaml
# File saved to: detect-nbtscan-activity.yaml
# Downloading: detect-suspicious-commands-initiated-by-web-server-processes.yaml
# File saved to: detect-suspicious-commands-initiated-by-web-server-processes.yaml
# Downloading: doppelpaymer.yaml
# File saved to: doppelpaymer.yaml
# Downloading: qakbot-campaign-esentutl.yaml
# File saved to: qakbot-campaign-esentutl.yaml
# Downloading: qakbot-campaign-outlook.yaml
# File saved to: qakbot-campaign-outlook.yaml
# Exiting directory: Discovery
# Entering directory: Email Queries
# Downloading: Appspot Phishing Abuse.yaml
# File saved to: Appspot Phishing Abuse.yaml
# Downloading: Email-RemediationAction-List.yaml
# File saved to: Email-RemediationAction-List.yaml
# Downloading: JNLP-File-Attachment.yaml
# File saved to: JNLP-File-Attachment.yaml
# Downloading: PhishingEmailUrlRedirector (1).yaml
# File saved to: PhishingEmailUrlRedirector (1).yaml
# Downloading: PhishingEmailUrlRedirector.yaml
# File saved to: PhishingEmailUrlRedirector.yaml
# Downloading: referral-phish-emails.yaml
# File saved to: referral-phish-emails.yaml
# Exiting directory: Email Queries
# Entering directory: Execution
# Downloading: Base64 Detector and Decoder.yaml
# File saved to: Base64 Detector and Decoder.yaml
# Downloading: Base64encodePEFile.yaml
# File saved to: Base64encodePEFile.yaml
# Downloading: Bitsadmin Activity.yaml
# File saved to: Bitsadmin Activity.yaml
# Downloading: Detect Encoded Powershell.yaml
# File saved to: Detect Encoded Powershell.yaml
# Downloading: Detect PowerShell v2 Downgrade.yaml
# File saved to: Detect PowerShell v2 Downgrade.yaml
# Downloading: ExecuteBase64DecodedPayload.yaml
# File saved to: ExecuteBase64DecodedPayload.yaml
# Downloading: File Copy and Execution.yaml
# File saved to: File Copy and Execution.yaml
# Downloading: Malware_In_recyclebin.yaml
# File saved to: Malware_In_recyclebin.yaml
# Downloading: Masquerading system executable.yaml
# File saved to: Masquerading system executable.yaml
# Downloading: Possible Ransomware Related Destruction Activity.yaml
# File saved to: Possible Ransomware Related Destruction Activity.yaml
# Downloading: PowerShell downloads.yaml
# File saved to: PowerShell downloads.yaml
# Downloading: PowershellCommand - uncommon commands on machine.yaml
# File saved to: PowershellCommand - uncommon commands on machine.yaml
# Downloading: PowershellCommand footprint.yaml
# File saved to: PowershellCommand footprint.yaml
# Downloading: Webserver Executing Suspicious Applications.yaml
# File saved to: Webserver Executing Suspicious Applications.yaml
# Downloading: anomalous-payload-delivered-from-iso-file.yaml
# File saved to: anomalous-payload-delivered-from-iso-file.yaml
# Downloading: check-for-shadowhammer-activity-implant.yaml
# File saved to: check-for-shadowhammer-activity-implant.yaml
# Downloading: detect-anomalous-process-trees.yaml
# File saved to: detect-anomalous-process-trees.yaml
# Downloading: detect-bluekeep-related-mining.yaml
# File saved to: detect-bluekeep-related-mining.yaml
# Downloading: detect-doublepulsar-execution.yaml
# File saved to: detect-doublepulsar-execution.yaml
# Downloading: detect-exploitation-of-cve-2018-8653.yaml
# File saved to: detect-exploitation-of-cve-2018-8653.yaml
# Downloading: detect-malicious-rar-extraction.yaml
# File saved to: detect-malicious-rar-extraction.yaml
# Downloading: detect-malicious-use-of-msiexec-mimikatz.yaml
# File saved to: detect-malicious-use-of-msiexec-mimikatz.yaml
# Downloading: detect-malicious-use-of-msiexec-msiexec.yaml
# File saved to: detect-malicious-use-of-msiexec-msiexec.yaml
# Downloading: detect-malicious-use-of-msiexec-powershell.yaml
# File saved to: detect-malicious-use-of-msiexec-powershell.yaml
# Downloading: detect-office-apps-spawn-msdt-CVE-2022-30190.yaml
# File saved to: detect-office-apps-spawn-msdt-CVE-2022-30190.yaml
# Downloading: detect-office-products-spawning-wmic.yaml
# File saved to: detect-office-products-spawning-wmic.yaml
# Downloading: detect-potential-kerberoast-activities.yaml
# File saved to: detect-potential-kerberoast-activities.yaml
# Downloading: detect-suspicious-mshta-usage.yaml
# File saved to: detect-suspicious-mshta-usage.yaml
# Downloading: detect-uac-elevation.yml
# File saved to: detect-uac-elevation.yml
# Downloading: detect-web-server-exploit-doublepulsar.yaml
# File saved to: detect-web-server-exploit-doublepulsar.yaml
# Downloading: exchange-iis-worker-dropping-webshell.yaml
# File saved to: exchange-iis-worker-dropping-webshell.yaml
# Downloading: jse-launched-by-word.yaml
# File saved to: jse-launched-by-word.yaml
# Downloading: launch-questd-w-osascript.yaml
# File saved to: launch-questd-w-osascript.yaml
# Downloading: locate-shlayer-payload-decryption-activity.yaml
# File saved to: locate-shlayer-payload-decryption-activity.yaml
# Downloading: locate-shlayer-payload-decrytion-activity.yaml
# File saved to: locate-shlayer-payload-decrytion-activity.yaml
# Downloading: locate-surfbuyer-downloader-decoding-activity.yaml
# File saved to: locate-surfbuyer-downloader-decoding-activity.yaml
# Downloading: office-apps-launching-wscipt.yaml
# File saved to: office-apps-launching-wscipt.yaml
# Downloading: powershell-activity-after-email-from-malicious-sender.yaml
# File saved to: powershell-activity-after-email-from-malicious-sender.yaml
# Downloading: powershell-version-2.0-execution.yaml
# File saved to: powershell-version-2.0-execution.yaml
# Downloading: python-based-attacks-on-macos.yaml
# File saved to: python-based-attacks-on-macos.yaml
# Downloading: qakbot-campaign-suspicious-javascript.yaml
# File saved to: qakbot-campaign-suspicious-javascript.yaml
# Downloading: reverse-shell-nishang-base64.yaml
# File saved to: reverse-shell-nishang-base64.yaml
# Downloading: reverse-shell-nishang.yaml
# File saved to: reverse-shell-nishang.yaml
# Downloading: sql-server-abuse.yaml
# File saved to: sql-server-abuse.yaml
# Downloading: umworkerprocess-creating-webshell.yaml
# File saved to: umworkerprocess-creating-webshell.yaml
# Downloading: umworkerprocess-unusual-subprocess-activity.yaml
# File saved to: umworkerprocess-unusual-subprocess-activity.yaml
# Exiting directory: Execution
# Entering directory: Exfiltration
# Downloading: 7-zip-prep-for-exfiltration.yaml
# File saved to: 7-zip-prep-for-exfiltration.yaml
# Downloading: Anomaly of MailItemAccess by GraphAPI [Nobelium].yaml
# File saved to: Anomaly of MailItemAccess by GraphAPI [Nobelium].yaml
# Downloading: Data copied to other location than C drive.yaml
# File saved to: Data copied to other location than C drive.yaml
# Downloading: Files copied to USB drives.yaml
# File saved to: Files copied to USB drives.yaml
# Downloading: MailItemsAccessed Throttling [Nobelium].yaml
# File saved to: MailItemsAccessed Throttling [Nobelium].yaml
# Downloading: Map external devices (1).yaml
# File saved to: Map external devices (1).yaml
# Downloading: Map external devices.yaml
# File saved to: Map external devices.yaml
# Downloading: OAuth Apps accessing user mail via GraphAPI [Nobelium].yaml
# File saved to: OAuth Apps accessing user mail via GraphAPI [Nobelium].yaml
# Downloading: OAuth Apps reading mail both via GraphAPI and directly [Nobelium].yaml
# File saved to: OAuth Apps reading mail both via GraphAPI and directly [Nobelium].yaml
# Downloading: OAuth Apps reading mail via GraphAPI anomaly [Nobelium].yaml
# File saved to: OAuth Apps reading mail via GraphAPI anomaly [Nobelium].yaml
# Downloading: Password Protected Archive Creation.yaml
# File saved to: Password Protected Archive Creation.yaml
# Downloading: Possible File Copy to USB Drive.yaml
# File saved to: Possible File Copy to USB Drive.yaml
# Downloading: codeRepoExfil.yaml
# File saved to: codeRepoExfil.yaml
# Downloading: detect-archive-exfiltration-to-competitor.yaml
# File saved to: detect-archive-exfiltration-to-competitor.yaml
# Downloading: detect-exfiltration-after-termination.yaml
# File saved to: detect-exfiltration-after-termination.yaml
# Downloading: detect-steganography-exfiltration.yaml
# File saved to: detect-steganography-exfiltration.yaml
# Downloading: exchange-powershell-snapin-loaded.yaml
# File saved to: exchange-powershell-snapin-loaded.yaml
# Downloading: unusual-volume-of-file-sharing.yaml
# File saved to: unusual-volume-of-file-sharing.yaml
# Exiting directory: Exfiltration
# Entering directory: Exploits
# Downloading: AcroRd-Exploits.yaml
# File saved to: AcroRd-Exploits.yaml
# Downloading: CVE-2021-36934 usage detection.yaml
# File saved to: CVE-2021-36934 usage detection.yaml
# Downloading: CVE-2022-22965 Network Activity.yaml
# File saved to: CVE-2022-22965 Network Activity.yaml
# Downloading: CVE-2022-26134-Confluence.yaml
# File saved to: CVE-2022-26134-Confluence.yaml
# Downloading: Electron-CVE-2018-1000006.yaml
# File saved to: Electron-CVE-2018-1000006.yaml
# Downloading: Flash-CVE-2018-4848.yaml
# File saved to: Flash-CVE-2018-4848.yaml
# Downloading: Linux-DynoRoot-CVE-2018-1111.yaml
# File saved to: Linux-DynoRoot-CVE-2018-1111.yaml
# Downloading: MosaicLoader.yaml
# File saved to: MosaicLoader.yaml
# Entering subdirectory: Print Spooler RCE
# Downloading: Spoolsv Spawning Rundll32.yaml
# File saved to: Spoolsv Spawning Rundll32.yaml
# Downloading: Suspicious DLLs in spool folder.yaml
# File saved to: Suspicious DLLs in spool folder.yaml
# Downloading: Suspicious Spoolsv Child Process.yaml
# File saved to: Suspicious Spoolsv Child Process.yaml
# Downloading: Suspicious files in spool folder.yaml
# File saved to: Suspicious files in spool folder.yaml
# Exiting subdirectory: Print Spooler RCE
# Downloading: SolarWinds -CVE-2021-35211.yaml
# File saved to: SolarWinds -CVE-2021-35211.yaml
# Downloading: VMWare-LPE-2022-22960.yaml
# File saved to: VMWare-LPE-2022-22960.yaml
# Downloading: print-pooler-service-suspicious-file-creation.yaml
# File saved to: print-pooler-service-suspicious-file-creation.yaml
# Downloading: printnightmare-cve-2021-1675 usage detection (1).yaml
# File saved to: printnightmare-cve-2021-1675 usage detection (1).yaml
# Downloading: printnightmare-cve-2021-1675 usage detection.yaml
# File saved to: printnightmare-cve-2021-1675 usage detection.yaml
# Downloading: winrar-cve-2018-20250-ace-files.yaml
# File saved to: winrar-cve-2018-20250-ace-files.yaml
# Downloading: winrar-cve-2018-20250-file-creation.yaml
# File saved to: winrar-cve-2018-20250-file-creation.yaml
# Exiting directory: Exploits
# Entering directory: Fun
# Downloading: EmojiHunt.yaml
# File saved to: EmojiHunt.yaml
# Downloading: Make FolderPath Vogon Poetry.yaml
# File saved to: Make FolderPath Vogon Poetry.yaml
# Exiting directory: Fun
# Entering directory: General queries
# Downloading: Alert Events from Internal IP Address.yaml
# File saved to: Alert Events from Internal IP Address.yaml
# Downloading: AppLocker Policy Design Assistant.yaml
# File saved to: AppLocker Policy Design Assistant.yaml
# Downloading: Baseline Comparison.yaml
# File saved to: Baseline Comparison.yaml
# Downloading: Crashing Applications.yaml
# File saved to: Crashing Applications.yaml
# Downloading: Detect Azure RemoteIP.yaml
# File saved to: Detect Azure RemoteIP.yaml
# Downloading: Device Count by DNS Suffix.yaml
# File saved to: Device Count by DNS Suffix.yaml
# Downloading: Device uptime calculation.yaml
# File saved to: Device uptime calculation.yaml
# Downloading: Endpoint Agent Health Status Report.yaml
# File saved to: Endpoint Agent Health Status Report.yaml
# Downloading: Endpoint Linux AV Signature and Platform Versions
# File saved to: Endpoint Linux AV Signature and Platform Versions
# Downloading: Endpoint Linux Agent Health Status Report
# File saved to: Endpoint Linux Agent Health Status Report
# Downloading: Events surrounding alert (1).yaml
# File saved to: Events surrounding alert (1).yaml
# Downloading: Events surrounding alert (2).yaml
# File saved to: Events surrounding alert (2).yaml
# Downloading: Events surrounding alert (3).yaml
# File saved to: Events surrounding alert (3).yaml
# Downloading: Events surrounding alert.yaml
# File saved to: Events surrounding alert.yaml
# Downloading: Failed Logon Attempt.yaml
# File saved to: Failed Logon Attempt.yaml
# Downloading: File footprint (1).yaml
# File saved to: File footprint (1).yaml
# Downloading: File footprint.yaml
# File saved to: File footprint.yaml
# Downloading: Firewall Policy Design Assistant.yaml
# File saved to: Firewall Policy Design Assistant.yaml
# Downloading: Linux Agent Age Report.yaml
# File saved to: Linux Agent Age Report.yaml
# Downloading: MD AV Signature and Platform Version.yaml
# File saved to: MD AV Signature and Platform Version.yaml
# Downloading: MITRE - Suspicious Events.yaml
# File saved to: MITRE - Suspicious Events.yaml
# Downloading: Machine info from IP address (1).yaml
# File saved to: Machine info from IP address (1).yaml
# Downloading: Machine info from IP address (2).yaml
# File saved to: Machine info from IP address (2).yaml
# Downloading: Machine info from IP address (3).yaml
# File saved to: Machine info from IP address (3).yaml
# Downloading: Machine info from IP address.yaml
# File saved to: Machine info from IP address.yaml
# Downloading: Network footprint (1).yaml
# File saved to: Network footprint (1).yaml
# Downloading: Network footprint (2).yaml
# File saved to: Network footprint (2).yaml
# Downloading: Network footprint (3).yaml
# File saved to: Network footprint (3).yaml
# Downloading: Network footprint.yaml
# File saved to: Network footprint.yaml
# Downloading: Network info of machine.yaml
# File saved to: Network info of machine.yaml
# Downloading: Phish and Malware received by user vs total amount of email.yaml
# File saved to: Phish and Malware received by user vs total amount of email.yaml
# Downloading: Services.yaml
# File saved to: Services.yaml
# Downloading: System Guard Security Level Baseline.yaml
# File saved to: System Guard Security Level Baseline.yaml
# Downloading: System Guard Security Level Drop.yaml
# File saved to: System Guard Security Level Drop.yaml
# Downloading: Web Content Filtering Events.yml
# File saved to: Web Content Filtering Events.yml
# Downloading: insider-threat-detection-queries (1).yaml
# File saved to: insider-threat-detection-queries (1).yaml
# Downloading: insider-threat-detection-queries (10).yaml
# File saved to: insider-threat-detection-queries (10).yaml
# Downloading: insider-threat-detection-queries (11).yaml
# File saved to: insider-threat-detection-queries (11).yaml
# Downloading: insider-threat-detection-queries (12).yaml
# File saved to: insider-threat-detection-queries (12).yaml
# Downloading: insider-threat-detection-queries (13).yaml
# File saved to: insider-threat-detection-queries (13).yaml
# Downloading: insider-threat-detection-queries (14).yaml
# File saved to: insider-threat-detection-queries (14).yaml
# Downloading: insider-threat-detection-queries (15).yaml
# File saved to: insider-threat-detection-queries (15).yaml
# Downloading: insider-threat-detection-queries (16).yaml
# File saved to: insider-threat-detection-queries (16).yaml
# Downloading: insider-threat-detection-queries (17).yaml
# File saved to: insider-threat-detection-queries (17).yaml
# Downloading: insider-threat-detection-queries (18).yaml
# File saved to: insider-threat-detection-queries (18).yaml
# Downloading: insider-threat-detection-queries (19).yaml
# File saved to: insider-threat-detection-queries (19).yaml
# Downloading: insider-threat-detection-queries (2).yaml
# File saved to: insider-threat-detection-queries (2).yaml
# Downloading: insider-threat-detection-queries (3).yaml
# File saved to: insider-threat-detection-queries (3).yaml
# Downloading: insider-threat-detection-queries (4).yaml
# File saved to: insider-threat-detection-queries (4).yaml
# Downloading: insider-threat-detection-queries (5).yaml
# File saved to: insider-threat-detection-queries (5).yaml
# Downloading: insider-threat-detection-queries (6).yaml
# File saved to: insider-threat-detection-queries (6).yaml
# Downloading: insider-threat-detection-queries (7).yaml
# File saved to: insider-threat-detection-queries (7).yaml
# Downloading: insider-threat-detection-queries (8).yaml
# File saved to: insider-threat-detection-queries (8).yaml
# Downloading: insider-threat-detection-queries (9).yaml
# File saved to: insider-threat-detection-queries (9).yaml
# Downloading: insider-threat-detection-queries.yaml
# File saved to: insider-threat-detection-queries.yaml
# Downloading: wifikeys.yaml
# File saved to: wifikeys.yaml
# Exiting directory: General queries
# Entering directory: Impact
# Downloading: backup-deletion.yaml
# File saved to: backup-deletion.yaml
# Downloading: ransom-note-creation-macos.yaml
# File saved to: ransom-note-creation-macos.yaml
# Downloading: turn-off-system-restore.yaml
# File saved to: turn-off-system-restore.yaml
# Downloading: unusual-volume-of-file-deletion.yaml
# File saved to: unusual-volume-of-file-deletion.yaml
# Downloading: wadhrama-data-destruction.yaml
# File saved to: wadhrama-data-destruction.yaml
# Exiting directory: Impact
# Entering directory: Initial access
# Downloading: ActiveDirectory_Account_lockout_and_unlocks.yaml
# File saved to: ActiveDirectory_Account_lockout_and_unlocks.yaml
# Downloading: Check for Maalware Baazar (abuse.ch) hashes in your mail flow.yaml
# File saved to: Check for Maalware Baazar (abuse.ch) hashes in your mail flow.yaml
# Downloading: Detect DNS Obfuscation Using @ Symbol in Email URLs.yml
# File saved to: Detect DNS Obfuscation Using @ Symbol in Email URLs.yml
# Downloading: Non_intended_user_logon.yaml
# File saved to: Non_intended_user_logon.yaml
# Downloading: PhishingEmailUrlRedirector.yaml
# File saved to: PhishingEmailUrlRedirector.yaml
# Downloading: SuspiciousUrlClicked.yaml
# File saved to: SuspiciousUrlClicked.yaml
# Downloading: User navigation to redirected URL.yaml
# File saved to: User navigation to redirected URL.yaml
# Downloading: detect-bluekeep-exploitation-attempts.yaml
# File saved to: detect-bluekeep-exploitation-attempts.yaml
# Downloading: detect-mailsniper.yaml
# File saved to: detect-mailsniper.yaml
# Downloading: files-from-malicious-sender.yaml
# File saved to: files-from-malicious-sender.yaml
# Downloading: identify-potential-missed-phishing-email-campaigns.yaml
# File saved to: identify-potential-missed-phishing-email-campaigns.yaml
# Downloading: jar-attachments.yaml
# File saved to: jar-attachments.yaml
# Exiting directory: Initial access
# Entering directory: Lateral Movement
# Downloading: Account brute force (1).yaml
# File saved to: Account brute force (1).yaml
# Downloading: Account brute force.yaml
# File saved to: Account brute force.yaml
# Downloading: Device Logons from Unknown IPs.yaml
# File saved to: Device Logons from Unknown IPs.yaml
# Downloading: ImpersonatedUserFootprint.yaml
# File saved to: ImpersonatedUserFootprint.yaml
# Downloading: NegoExLogins
# File saved to: NegoExLogins
# Downloading: Network Logons with Local Accounts.yaml
# File saved to: Network Logons with Local Accounts.yaml
# Downloading: Non-local logons with -500 account.yaml
# File saved to: Non-local logons with -500 account.yaml
# Downloading: ServiceAccountsPerformingRemotePS.yaml
# File saved to: ServiceAccountsPerformingRemotePS.yaml
# Downloading: detect-suspicious-rdp-connections.yaml
# File saved to: detect-suspicious-rdp-connections.yaml
# Downloading: doppelpaymer-psexec.yaml
# File saved to: doppelpaymer-psexec.yaml
# Downloading: remote-file-creation-with-psexec.yaml
# File saved to: remote-file-creation-with-psexec.yaml
# Exiting directory: Lateral Movement
# Entering directory: Network
# Downloading: Defender for Endpoint Telemetry.yaml
# File saved to: Defender for Endpoint Telemetry.yaml
# Exiting directory: Network
# Entering directory: Persistence
# Downloading: Accessibility Features.yaml
# File saved to: Accessibility Features.yaml
# Downloading: AddedCredentialFromContryXAndSigninFromCountryY.yaml
# File saved to: AddedCredentialFromContryXAndSigninFromCountryY.yaml
# Downloading: Create account (1).yaml
# File saved to: Create account (1).yaml
# Downloading: Create account.yaml
# File saved to: Create account.yaml
# Downloading: CredentialsAddAfterAdminConsentedToApp[Nobelium].yaml
# File saved to: CredentialsAddAfterAdminConsentedToApp[Nobelium].yaml
# Downloading: LocalAdminGroupChanges.yaml
# File saved to: LocalAdminGroupChanges.yaml
# Downloading: NewAppOrServicePrincipalCredential[Nobelium].yaml
# File saved to: NewAppOrServicePrincipalCredential[Nobelium].yaml
# Downloading: Possible webshell drop.yaml
# File saved to: Possible webshell drop.yaml
# Downloading: Rare-process-as-a-service.yaml
# File saved to: Rare-process-as-a-service.yaml
# Downloading: detect-prifou-pua.yaml
# File saved to: detect-prifou-pua.yaml
# Downloading: localAdminAccountLogon.yaml
# File saved to: localAdminAccountLogon.yaml
# Downloading: multipleAADAdminsRemovals.yaml
# File saved to: multipleAADAdminsRemovals.yaml
# Downloading: qakbot-campaign-registry-edit.yaml
# File saved to: qakbot-campaign-registry-edit.yaml
# Downloading: riskySignInToDeviceRegistration.yaml
# File saved to: riskySignInToDeviceRegistration.yaml
# Downloading: riskySignInToNewMFAMethod.yaml
# File saved to: riskySignInToNewMFAMethod.yaml
# Downloading: scheduled task creation.yaml
# File saved to: scheduled task creation.yaml
# Downloading: wadhrama-ransomware.yaml
# File saved to: wadhrama-ransomware.yaml
# Exiting directory: Persistence
# Entering directory: Privilege escalation
# Downloading: Add uncommon credential type to application [Nobelium].yaml
# File saved to: Add uncommon credential type to application [Nobelium].yaml
# Downloading: SAM-Name-Changes-CVE-2021-42278.yaml
# File saved to: SAM-Name-Changes-CVE-2021-42278.yaml
# Downloading: ServicePrincipalAddedToRole [Nobelium].yaml
# File saved to: ServicePrincipalAddedToRole [Nobelium].yaml
# Downloading: cve-2019-0808-c2.yaml
# File saved to: cve-2019-0808-c2.yaml
# Downloading: cve-2019-0808-nufsys-file creation.yaml
# File saved to: cve-2019-0808-nufsys-file creation.yaml
# Downloading: cve-2019-0808-set-scheduled-task.yaml
# File saved to: cve-2019-0808-set-scheduled-task.yaml
# Downloading: dell-driver-vulnerability-2021.yaml
# File saved to: dell-driver-vulnerability-2021.yaml
# Downloading: detect-av-edr-privileged-delete-vulnerability.yaml
# File saved to: detect-av-edr-privileged-delete-vulnerability.yaml
# Downloading: detect-cve-2019-0863-AngryPolarBearBug2-exploit.yaml
# File saved to: detect-cve-2019-0863-AngryPolarBearBug2-exploit.yaml
# Downloading: detect-cve-2019-0973-installerbypass-exploit.yaml
# File saved to: detect-cve-2019-0973-installerbypass-exploit.yaml
# Downloading: detect-cve-2019-1053-sandboxescape-exploit.yaml
# File saved to: detect-cve-2019-1053-sandboxescape-exploit.yaml
# Downloading: detect-cve-2019-1069-bearlpe-exploit.yaml
# File saved to: detect-cve-2019-1069-bearlpe-exploit.yaml
# Downloading: detect-cve-2019-1129-byebear-exploit.yaml
# File saved to: detect-cve-2019-1129-byebear-exploit.yaml
# Downloading: locate-ALPC-local-privilege-elevation-exploit.yaml
# File saved to: locate-ALPC-local-privilege-elevation-exploit.yaml
# Downloading: riskySignInToElevateAccess.yaml
# File saved to: riskySignInToElevateAccess.yaml
# Exiting directory: Privilege escalation
# Entering directory: Protection events
# Downloading: AV Detections with Source.yaml
# File saved to: AV Detections with Source.yaml
# Downloading: AV Detections with USB Disk Drive.yaml
# File saved to: AV Detections with USB Disk Drive.yaml
# Downloading: Antivirus detections (1).yaml
# File saved to: Antivirus detections (1).yaml
# Downloading: Antivirus detections.yaml
# File saved to: Antivirus detections.yaml
# Downloading: ExploitGuardASRStats (1).yaml
# File saved to: ExploitGuardASRStats (1).yaml
# Downloading: ExploitGuardASRStats (2).yaml
# File saved to: ExploitGuardASRStats (2).yaml
# Downloading: ExploitGuardASRStats.yaml
# File saved to: ExploitGuardASRStats.yaml
# Downloading: ExploitGuardAsrDescriptions.yaml
# File saved to: ExploitGuardAsrDescriptions.yaml
# Downloading: ExploitGuardBlockOfficeChildProcess (1).yaml
# File saved to: ExploitGuardBlockOfficeChildProcess (1).yaml
# Downloading: ExploitGuardBlockOfficeChildProcess (2).yaml
# File saved to: ExploitGuardBlockOfficeChildProcess (2).yaml
# Downloading: ExploitGuardBlockOfficeChildProcess (3).yaml
# File saved to: ExploitGuardBlockOfficeChildProcess (3).yaml
# Downloading: ExploitGuardBlockOfficeChildProcess.yaml
# File saved to: ExploitGuardBlockOfficeChildProcess.yaml
# Downloading: ExploitGuardControlledFolderAccess (1).yaml
# File saved to: ExploitGuardControlledFolderAccess (1).yaml
# Downloading: ExploitGuardControlledFolderAccess (2).yaml
# File saved to: ExploitGuardControlledFolderAccess (2).yaml
# Downloading: ExploitGuardControlledFolderAccess.yaml
# File saved to: ExploitGuardControlledFolderAccess.yaml
# Downloading: ExploitGuardNetworkProtectionEvents.yaml
# File saved to: ExploitGuardNetworkProtectionEvents.yaml
# Downloading: ExploitGuardStats (1).yaml
# File saved to: ExploitGuardStats (1).yaml
# Downloading: ExploitGuardStats.yaml
# File saved to: ExploitGuardStats.yaml
# Downloading: PUA ThreatName per Computer.yaml
# File saved to: PUA ThreatName per Computer.yaml
# Downloading: SmartScreen URL block ignored by user.yaml
# File saved to: SmartScreen URL block ignored by user.yaml
# Downloading: SmartScreen app block ignored by user.yaml
# File saved to: SmartScreen app block ignored by user.yaml
# Downloading: Windows filtering events (Firewall).yaml
# File saved to: Windows filtering events (Firewall).yaml
# Exiting directory: Protection events
# Entering directory: Ransomware
# Downloading: ASR--Rule-Ransomware-triggered.yaml
# File saved to: ASR--Rule-Ransomware-triggered.yaml
# Downloading: Backup deletion.yaml
# File saved to: Backup deletion.yaml
# ...
# Downloading: Sticky Keys.yaml
# File saved to: Sticky Keys.yaml
# Downloading: Stopping multiple processes using taskkill.yaml
# File saved to: Stopping multiple processes using taskkill.yaml
# Downloading: Stopping processes using net stop.yaml
# File saved to: Stopping processes using net stop.yaml
# Downloading: Suspicious Bitlocker Encryption.yaml
# File saved to: Suspicious Bitlocker Encryption.yaml
# Downloading: Suspicious Google Doc Links.yaml
# File saved to: Suspicious Google Doc Links.yaml
# Downloading: Suspicious Image Load related to IcedId.yaml
# File saved to: Suspicious Image Load related to IcedId.yaml
# Downloading: Turning off System Restore.yaml
# File saved to: Turning off System Restore.yaml
# Downloading: Turning off services using sc exe.yaml
# File saved to: Turning off services using sc exe.yaml
# Exiting directory: Ransomware
# Entering directory: RemoteManagementMonitoring
# Downloading: rmm_Action1_createproc.yaml
# File saved to: rmm_Action1_createproc.yaml
# Downloading: rmm_Action1_filesig.yaml
# File saved to: rmm_Action1_filesig.yaml
# Downloading: rmm_Action1_netconn.yaml
# File saved to: rmm_Action1_netconn.yaml
# Downloading: rmm_Addigy_netconn.yaml
# File saved to: rmm_Addigy_netconn.yaml
# Downloading: rmm_AeroAdmin_createproc.yaml
# File saved to: rmm_AeroAdmin_createproc.yaml
# Downloading: rmm_AeroAdmin_filesig.yaml
# File saved to: rmm_AeroAdmin_filesig.yaml
# Downloading: rmm_AeroAdmin_netconn.yaml
# File saved to: rmm_AeroAdmin_netconn.yaml
# Downloading: rmm_Ammyy_createproc.yaml
# File saved to: rmm_Ammyy_createproc.yaml
# Downloading: rmm_Ammyy_filesig.yaml
# File saved to: rmm_Ammyy_filesig.yaml
# Downloading: rmm_Ammyy_netconn.yaml
# File saved to: rmm_Ammyy_netconn.yaml
# Downloading: rmm_AnyDesk_createproc.yaml
# File saved to: rmm_AnyDesk_createproc.yaml
# Downloading: rmm_AnyDesk_filesig.yaml
# File saved to: rmm_AnyDesk_filesig.yaml
# Downloading: rmm_AnyDesk_netconn.yaml
# File saved to: rmm_AnyDesk_netconn.yaml
# Downloading: rmm_AnyViewer_createproc.yaml
# File saved to: rmm_AnyViewer_createproc.yaml
# Downloading: rmm_AnyViewer_filesig.yaml
# File saved to: rmm_AnyViewer_filesig.yaml
# Downloading: rmm_AnyViewer_netconn.yaml
# File saved to: rmm_AnyViewer_netconn.yaml
# Downloading: rmm_Atera_createproc.yaml
# File saved to: rmm_Atera_createproc.yaml
# Downloading: rmm_Atera_filesig.yaml
# File saved to: rmm_Atera_filesig.yaml
# Downloading: rmm_Atera_netconn.yaml
# File saved to: rmm_Atera_netconn.yaml
# Downloading: rmm_AweSun_createproc.yaml
# File saved to: rmm_AweSun_createproc.yaml
# Downloading: rmm_AweSun_filesig.yaml
# File saved to: rmm_AweSun_filesig.yaml
# Downloading: rmm_AweSun_netconn.yaml
# File saved to: rmm_AweSun_netconn.yaml
# Downloading: rmm_BarracudaRMM_createproc.yaml
# File saved to: rmm_BarracudaRMM_createproc.yaml
# Downloading: rmm_BarracudaRMM_filesig.yaml
# File saved to: rmm_BarracudaRMM_filesig.yaml
# Downloading: rmm_BarracudaRMM_netconn.yaml
# File saved to: rmm_BarracudaRMM_netconn.yaml
# Downloading: rmm_BeyondTrust_createproc.yaml
# File saved to: rmm_BeyondTrust_createproc.yaml
# Downloading: rmm_BeyondTrust_filesig.yaml
# File saved to: rmm_BeyondTrust_filesig.yaml
# Downloading: rmm_BeyondTrust_netconn.yaml
# File saved to: rmm_BeyondTrust_netconn.yaml
# Downloading: rmm_ChromeRDP_createproc.yaml
# File saved to: rmm_ChromeRDP_createproc.yaml
# Downloading: rmm_ChromeRDP_netconn.yaml
# File saved to: rmm_ChromeRDP_netconn.yaml
# Downloading: rmm_ConnectWise_createproc.yaml
# File saved to: rmm_ConnectWise_createproc.yaml
# Downloading: rmm_ConnectWise_filesig.yaml
# File saved to: rmm_ConnectWise_filesig.yaml
# Downloading: rmm_ConnectWise_netconn.yaml
# File saved to: rmm_ConnectWise_netconn.yaml
# Downloading: rmm_DWService_filesig.yaml
# File saved to: rmm_DWService_filesig.yaml
# Downloading: rmm_DameWare_createproc.yaml
# File saved to: rmm_DameWare_createproc.yaml
# Downloading: rmm_DameWare_filesig.yaml
# File saved to: rmm_DameWare_filesig.yaml
# Downloading: rmm_DameWare_netconn.yaml
# File saved to: rmm_DameWare_netconn.yaml
# Downloading: rmm_DattoRMM_filesig.yaml
# File saved to: rmm_DattoRMM_filesig.yaml
# Downloading: rmm_DattoRMM_netconn.yaml
# File saved to: rmm_DattoRMM_netconn.yaml
# Downloading: rmm_DesktopNow_createproc.yaml
# File saved to: rmm_DesktopNow_createproc.yaml
# Downloading: rmm_DesktopNow_filesig.yaml
# File saved to: rmm_DesktopNow_filesig.yaml
# Downloading: rmm_DesktopNow_netconn.yaml
# File saved to: rmm_DesktopNow_netconn.yaml
# Downloading: rmm_DistantDesktop_createproc.yaml
# File saved to: rmm_DistantDesktop_createproc.yaml
# Downloading: rmm_DistantDesktop_filesig.yaml
# File saved to: rmm_DistantDesktop_filesig.yaml
# Downloading: rmm_DistantDesktop_netconn.yaml
# File saved to: rmm_DistantDesktop_netconn.yaml
# Downloading: rmm_FleetDeck_createproc.yaml
# File saved to: rmm_FleetDeck_createproc.yaml
# Downloading: rmm_FleetDeck_filesig.yaml
# File saved to: rmm_FleetDeck_filesig.yaml
# Downloading: rmm_FleetDeck_netconn.yaml
# File saved to: rmm_FleetDeck_netconn.yaml
# Downloading: rmm_GetScreen_createproc.yaml
# File saved to: rmm_GetScreen_createproc.yaml
# Downloading: rmm_GetScreen_filesig.yaml
# File saved to: rmm_GetScreen_filesig.yaml
# Downloading: rmm_GetScreen_netconn.yaml
# File saved to: rmm_GetScreen_netconn.yaml
# Downloading: rmm_ISLOnline_createproc.yaml
# File saved to: rmm_ISLOnline_createproc.yaml
# Downloading: rmm_ISLOnline_filesig.yaml
# File saved to: rmm_ISLOnline_filesig.yaml
# Downloading: rmm_ISLOnline_netconn.yaml
# File saved to: rmm_ISLOnline_netconn.yaml
# Downloading: rmm_IperiusRemote_createproc.yaml
# File saved to: rmm_IperiusRemote_createproc.yaml
# Downloading: rmm_IperiusRemote_filesig.yaml
# File saved to: rmm_IperiusRemote_filesig.yaml
# Downloading: rmm_IperiusRemote_netconn.yaml
# File saved to: rmm_IperiusRemote_netconn.yaml
# Downloading: rmm_Kaseya_filesig.yaml
# File saved to: rmm_Kaseya_filesig.yaml
# Downloading: rmm_Kaseya_netconn.yaml
# File saved to: rmm_Kaseya_netconn.yaml
# Downloading: rmm_Level_createproc.yaml
# File saved to: rmm_Level_createproc.yaml
# Downloading: rmm_Level_filesig.yaml
# File saved to: rmm_Level_filesig.yaml
# Downloading: rmm_Level_netconn.yaml
# File saved to: rmm_Level_netconn.yaml
# Downloading: rmm_LiteManager_createproc.yaml
# File saved to: rmm_LiteManager_createproc.yaml
# Downloading: rmm_LiteManager_filesig.yaml
# File saved to: rmm_LiteManager_filesig.yaml
# Downloading: rmm_LiteManager_netconn.yaml
# File saved to: rmm_LiteManager_netconn.yaml
# Downloading: rmm_LogMeIn_createproc.yaml
# File saved to: rmm_LogMeIn_createproc.yaml
# Downloading: rmm_LogMeIn_filesig.yaml
# File saved to: rmm_LogMeIn_filesig.yaml
# Downloading: rmm_LogMeIn_netconn.yaml
# File saved to: rmm_LogMeIn_netconn.yaml
# Downloading: rmm_MSP360_CloudBerry_createproc.yaml
# File saved to: rmm_MSP360_CloudBerry_createproc.yaml
# Downloading: rmm_MSP360_CloudBerry_filesig.yaml
# File saved to: rmm_MSP360_CloudBerry_filesig.yaml
# Downloading: rmm_MSP360_CloudBerry_netconn.yaml
# File saved to: rmm_MSP360_CloudBerry_netconn.yaml
# Downloading: rmm_MeshCentral_createproc.yaml
# File saved to: rmm_MeshCentral_createproc.yaml
# Downloading: rmm_MeshCentral_filesig.yaml
# File saved to: rmm_MeshCentral_filesig.yaml
# Downloading: rmm_MeshCentral_netconn.yaml
# File saved to: rmm_MeshCentral_netconn.yaml
# Downloading: rmm_NAble_createproc.yaml
# File saved to: rmm_NAble_createproc.yaml
# Downloading: rmm_NAble_filesig.yaml
# File saved to: rmm_NAble_filesig.yaml
# Downloading: rmm_NAble_netconn.yaml
# File saved to: rmm_NAble_netconn.yaml
# Downloading: rmm_Naverisk_createproc.yaml
# File saved to: rmm_Naverisk_createproc.yaml
# Downloading: rmm_Naverisk_filesig.yaml
# File saved to: rmm_Naverisk_filesig.yaml
# Downloading: rmm_Naverisk_netconn.yaml
# File saved to: rmm_Naverisk_netconn.yaml
# Downloading: rmm_NetSupport_createproc.yaml
# File saved to: rmm_NetSupport_createproc.yaml
# Downloading: rmm_NetSupport_filesig.yaml
# File saved to: rmm_NetSupport_filesig.yaml
# Downloading: rmm_NetSupport_netconn.yaml
# File saved to: rmm_NetSupport_netconn.yaml
# Downloading: rmm_NinjaRMM_createproc.yaml
# File saved to: rmm_NinjaRMM_createproc.yaml
# Downloading: rmm_NinjaRMM_filesig.yaml
# File saved to: rmm_NinjaRMM_filesig.yaml
# Downloading: rmm_NinjaRMM_netconn.yaml
# File saved to: rmm_NinjaRMM_netconn.yaml
# Downloading: rmm_OptiTune_createproc.yaml
# File saved to: rmm_OptiTune_createproc.yaml
# Downloading: rmm_OptiTune_filesig.yaml
# File saved to: rmm_OptiTune_filesig.yaml
# Downloading: rmm_OptiTune_netconn.yaml
# File saved to: rmm_OptiTune_netconn.yaml
# Downloading: rmm_PDQ_createproc.yaml
# File saved to: rmm_PDQ_createproc.yaml
# Downloading: rmm_PDQ_filesig.yaml
# File saved to: rmm_PDQ_filesig.yaml
# Downloading: rmm_PDQ_netconn.yaml
# File saved to: rmm_PDQ_netconn.yaml
# Downloading: rmm_Panorama9_createproc.yaml
# File saved to: rmm_Panorama9_createproc.yaml
# Downloading: rmm_Panorama9_filesig.yaml
# File saved to: rmm_Panorama9_filesig.yaml
# Downloading: rmm_Panorama9_netconn.yaml
# File saved to: rmm_Panorama9_netconn.yaml
# Downloading: rmm_PcVisit_createproc.yaml
# File saved to: rmm_PcVisit_createproc.yaml
# Downloading: rmm_PcVisit_filesig.yaml
# File saved to: rmm_PcVisit_filesig.yaml
# Downloading: rmm_PcVisit_netconn.yaml
# File saved to: rmm_PcVisit_netconn.yaml
# Downloading: rmm_Pulseway_createproc.yaml
# File saved to: rmm_Pulseway_createproc.yaml
# Downloading: rmm_Pulseway_filesig.yaml
# File saved to: rmm_Pulseway_filesig.yaml
# Downloading: rmm_Pulseway_netconn.yaml
# File saved to: rmm_Pulseway_netconn.yaml
# Downloading: rmm_RPort_createproc.yaml
# File saved to: rmm_RPort_createproc.yaml
# Downloading: rmm_RPort_netconn.yaml
# File saved to: rmm_RPort_netconn.yaml
# Downloading: rmm_RealVNC_createproc.yaml
# File saved to: rmm_RealVNC_createproc.yaml
# Downloading: rmm_RealVNC_filesig.yaml
# File saved to: rmm_RealVNC_filesig.yaml
# Downloading: rmm_RealVNC_netconn.yaml
# File saved to: rmm_RealVNC_netconn.yaml
# Downloading: rmm_RemoteDesktopPlus_createproc.yaml
# File saved to: rmm_RemoteDesktopPlus_createproc.yaml
# Downloading: rmm_RemoteDesktopPlus_netconn.yaml
# File saved to: rmm_RemoteDesktopPlus_netconn.yaml
# Downloading: rmm_RemotePC_createproc.yaml
# File saved to: rmm_RemotePC_createproc.yaml
# Downloading: rmm_RemotePC_filesig.yaml
# File saved to: rmm_RemotePC_filesig.yaml
# Downloading: rmm_RemotePC_netconn.yaml
# File saved to: rmm_RemotePC_netconn.yaml
# Downloading: rmm_RemoteUtilities_createproc.yaml
# File saved to: rmm_RemoteUtilities_createproc.yaml
# Downloading: rmm_RemoteUtilities_filesig.yaml
# File saved to: rmm_RemoteUtilities_filesig.yaml
# Downloading: rmm_RemoteUtilities_netconn.yaml
# File saved to: rmm_RemoteUtilities_netconn.yaml
# Downloading: rmm_RustDesk_createproc.yaml
# File saved to: rmm_RustDesk_createproc.yaml
# Downloading: rmm_RustDesk_netconn.yaml
# File saved to: rmm_RustDesk_netconn.yaml
# Downloading: rmm_ScreenMeet_createproc.yaml
# File saved to: rmm_ScreenMeet_createproc.yaml
# Downloading: rmm_ScreenMeet_filesig.yaml
# File saved to: rmm_ScreenMeet_filesig.yaml
# Downloading: rmm_ScreenMeet_netconn.yaml
# File saved to: rmm_ScreenMeet_netconn.yaml
# Downloading: rmm_ServerEye_createproc.yaml
# File saved to: rmm_ServerEye_createproc.yaml
# Downloading: rmm_ServerEye_filesig.yaml
# File saved to: rmm_ServerEye_filesig.yaml
# Downloading: rmm_ServerEye_netconn.yaml
# File saved to: rmm_ServerEye_netconn.yaml
# Downloading: rmm_ShowMyPC_createproc.yaml
# File saved to: rmm_ShowMyPC_createproc.yaml
# Downloading: rmm_ShowMyPC_filesig.yaml
# File saved to: rmm_ShowMyPC_filesig.yaml
# Downloading: rmm_ShowMyPC_netconn.yaml
# File saved to: rmm_ShowMyPC_netconn.yaml
# Downloading: rmm_SimpleHelp_createproc.yaml
# File saved to: rmm_SimpleHelp_createproc.yaml
# Downloading: rmm_SimpleHelp_filesig.yaml
# File saved to: rmm_SimpleHelp_filesig.yaml
# Downloading: rmm_SimpleHelp_netconn.yaml
# File saved to: rmm_SimpleHelp_netconn.yaml
# Downloading: rmm_Splashtop_createproc.yaml
# File saved to: rmm_Splashtop_createproc.yaml
# Downloading: rmm_Splashtop_filesig.yaml
# File saved to: rmm_Splashtop_filesig.yaml
# Downloading: rmm_Splashtop_netconn.yaml
# File saved to: rmm_Splashtop_netconn.yaml
# Downloading: rmm_SupRemo_createproc.yaml
# File saved to: rmm_SupRemo_createproc.yaml
# Downloading: rmm_SupRemo_filesig.yaml
# File saved to: rmm_SupRemo_filesig.yaml
# Downloading: rmm_SupRemo_netconn.yaml
# File saved to: rmm_SupRemo_netconn.yaml
# Downloading: rmm_SyncroMSP_createproc.yaml
# File saved to: rmm_SyncroMSP_createproc.yaml
# Downloading: rmm_SyncroMSP_filesig.yaml
# File saved to: rmm_SyncroMSP_filesig.yaml
# Downloading: rmm_SyncroMSP_netconn.yaml
# File saved to: rmm_SyncroMSP_netconn.yaml
# Downloading: rmm_TacticalRMM_createproc.yaml
# File saved to: rmm_TacticalRMM_createproc.yaml
# Downloading: rmm_TacticalRMM_filesig.yaml
# File saved to: rmm_TacticalRMM_filesig.yaml
# Downloading: rmm_TacticalRMM_netconn.yaml
# File saved to: rmm_TacticalRMM_netconn.yaml
# Downloading: rmm_TeamViewer_createproc.yaml
# File saved to: rmm_TeamViewer_createproc.yaml
# Downloading: rmm_TeamViewer_filesig.yaml
# File saved to: rmm_TeamViewer_filesig.yaml
# Downloading: rmm_TeamViewer_netconn.yaml
# File saved to: rmm_TeamViewer_netconn.yaml
# Downloading: rmm_TigerVNC_createproc.yaml
# File saved to: rmm_TigerVNC_createproc.yaml
# Downloading: rmm_TigerVNC_netconn.yaml
# File saved to: rmm_TigerVNC_netconn.yaml
# Downloading: rmm_TightVNC_createproc.yaml
# File saved to: rmm_TightVNC_createproc.yaml
# Downloading: rmm_TightVNC_filesig.yaml
# File saved to: rmm_TightVNC_filesig.yaml
# Downloading: rmm_TightVNC_netconn.yaml
# File saved to: rmm_TightVNC_netconn.yaml
# Downloading: rmm_UltraViewer_createproc.yaml
# File saved to: rmm_UltraViewer_createproc.yaml
# Downloading: rmm_UltraViewer_filesig.yaml
# File saved to: rmm_UltraViewer_filesig.yaml
# Downloading: rmm_UltraViewer_netconn.yaml
# File saved to: rmm_UltraViewer_netconn.yaml
# Downloading: rmm_XMReality_createproc.yaml
# File saved to: rmm_XMReality_createproc.yaml
# Downloading: rmm_XMReality_filesig.yaml
# File saved to: rmm_XMReality_filesig.yaml
# Downloading: rmm_XMReality_netconn.yaml
# File saved to: rmm_XMReality_netconn.yaml
# Downloading: rmm_ZohoAssist_createproc.yaml
# File saved to: rmm_ZohoAssist_createproc.yaml
# Downloading: rmm_ZohoAssist_filesig.yaml
# File saved to: rmm_ZohoAssist_filesig.yaml
# Downloading: rmm_ZohoAssist_netconn.yaml
# File saved to: rmm_ZohoAssist_netconn.yaml
# Downloading: rmm__all_netconn.yaml
# File saved to: rmm__all_netconn.yaml
# Downloading: rmm_mRemoteNG_createproc.yaml
# File saved to: rmm_mRemoteNG_createproc.yaml
# Downloading: rmm_mRemoteNG_netconn.yaml
# File saved to: rmm_mRemoteNG_netconn.yaml
# Downloading: rmm_parsec.app_createproc.yaml
# File saved to: rmm_parsec.app_createproc.yaml
# Downloading: rmm_parsec.app_filesig.yaml
# File saved to: rmm_parsec.app_filesig.yaml
# Downloading: rmm_parsec.app_netconn.yaml
# File saved to: rmm_parsec.app_netconn.yaml
# Exiting directory: RemoteManagementMonitoring
# Entering directory: TVM
# Downloading: Detect_CISA_Alert_AA22-117A2021_Top_Routinely_Exploited_Vulnerabilities.yaml
# File saved to: Detect_CISA_Alert_AA22-117A2021_Top_Routinely_Exploited_Vulnerabilities.yaml
# Downloading: Microsoft Defender AV details.yaml
# File saved to: Microsoft Defender AV details.yaml
# Downloading: Microsoft Defender AV mode device count.yaml
# File saved to: Microsoft Defender AV mode device count.yaml
# Downloading: Microsoft Defender Anti virus Engine details.yaml
# File saved to: Microsoft Defender Anti virus Engine details.yaml
# Downloading: Microsoft Defender Anti virus Platform details.yaml
# File saved to: Microsoft Defender Anti virus Platform details.yaml
# Downloading: Microsoft Defender Anti virus Security Intelligence details.yaml
# File saved to: Microsoft Defender Anti virus Security Intelligence details.yaml
# Downloading: devices_with_vuln_and_users_received_payload (1).yaml
# File saved to: devices_with_vuln_and_users_received_payload (1).yaml
# Downloading: devices_with_vuln_and_users_received_payload.yaml
# File saved to: devices_with_vuln_and_users_received_payload.yaml
# Exiting directory: TVM
# Entering directory: Troubleshooting
# Downloading: Connectivity Failures by Device.yaml
# File saved to: Connectivity Failures by Device.yaml
# Downloading: Connectivity Failures by Domain.yaml
# File saved to: Connectivity Failures by Domain.yaml
# Exiting directory: Troubleshooting

# %%
import os
import yaml
import shutil
import time

def parse_yaml_and_organize(directory_path, output_directory):
    for root, dirs, files in os.walk(directory_path):
        for file_name in files:
            if file_name.endswith(".yaml"):
                file_path = os.path.join(root, file_name)

                print(f"Parsing YAML file: {file_path}")

                with open(file_path, 'r', encoding='utf-8') as file:
                    try:
                        yaml_data = yaml.safe_load(file)

                        # Check if requiredDataConnectors is a list
                        required_data_connectors = yaml_data.get('requiredDataConnectors', [])
                        if not isinstance(required_data_connectors, list):
                            required_data_connectors = [required_data_connectors]

                        for connector in required_data_connectors:
                            data_types = connector.get('dataTypes', [])

                            for data_type in data_types:
                                data_type_folder = os.path.join(output_directory, data_type)

                                # Create a folder for the data type if it doesn't exist
                                os.makedirs(data_type_folder, exist_ok=True)

                                # Copy the YAML file to the corresponding data type folder
                                new_file_path = os.path.join(data_type_folder, file_name)

                                # Add a delay before attempting to copy the file
                                time.sleep(0.1)

                                shutil.copy(file_path, new_file_path)

                                print(f"Copied {file_name} to {data_type_folder}")

                    except yaml.YAMLError as e:
                        print(f"Error parsing YAML file {file_path}: {e}")

# Path to the directory where files are downloaded
downloaded_directory = 'downloaded_files'
# Output directory for organized files
output_directory = 'files_parsed_by_nahed'

# Ensure the output directory exists and set permissions
os.makedirs(output_directory, exist_ok=True)
os.chmod(output_directory, 0o777)

# Parse YAML files and organize based on data types
parse_yaml_and_organize(downloaded_directory, output_directory)
# Out:
# Parsing YAML file: downloaded_files\ASR rules\ASR-rules-categorized-detection-graph.yaml
# Copied ASR-rules-categorized-detection-graph.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\Abuse.ch Recent Threat Feed (1).yaml
# Copied Abuse.ch Recent Threat Feed (1).yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied Abuse.ch Recent Threat Feed (1).yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied Abuse.ch Recent Threat Feed (1).yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\Abuse.ch Recent Threat Feed.yaml
# Copied Abuse.ch Recent Threat Feed.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied Abuse.ch Recent Threat Feed.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied Abuse.ch Recent Threat Feed.yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\Abusing settingcontent-ms.yaml
# Copied Abusing settingcontent-ms.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\APT Baby Shark.yaml
# Copied APT Baby Shark.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\apt sofacy zebrocy.yaml
# Copied apt sofacy zebrocy.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\apt sofacy.yaml
# Copied apt sofacy.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\apt ta17 293a ps.yaml
# Copied apt ta17 293a ps.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\apt tropictrooper.yaml
# Copied apt tropictrooper.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\apt unidentified nov 18 (1).yaml
# Copied apt unidentified nov 18 (1).yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\apt unidentified nov 18.yaml
# Copied apt unidentified nov 18.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\APT29 thinktanks.yaml
# Copied APT29 thinktanks.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Bear Activity GTR 2019.yaml
# Copied Bear Activity GTR 2019.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\c2-lookup-from-nonbrowser[Nobelium] (1).yaml
# Copied c2-lookup-from-nonbrowser[Nobelium] (1).yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Campaigns\c2-lookup-from-nonbrowser[Nobelium].yaml
# Copied c2-lookup-from-nonbrowser[Nobelium].yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\c2-lookup-response[Nobelium] (1).yaml
# Copied c2-lookup-response[Nobelium] (1).yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Campaigns\c2-lookup-response[Nobelium].yaml
# Copied c2-lookup-response[Nobelium].yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\Cloud Hopper.yaml
# Copied Cloud Hopper.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\cobalt-strike-invoked-w-wmi.yaml
# Copied cobalt-strike-invoked-w-wmi.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\compromised nvidia certificates[Lapsus$].yaml
# Copied compromised nvidia certificates[Lapsus$].yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Copied compromised nvidia certificates[Lapsus$].yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\compromised-certificate[Nobelium].yaml
# Copied compromised-certificate[Nobelium].yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Copied compromised-certificate[Nobelium].yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\confluence-weblogic-targeted.yaml
# Copied confluence-weblogic-targeted.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\cypherpunk-exclusive-commands.yaml
# Copied cypherpunk-exclusive-commands.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\cypherpunk-remote-exec-w-psexesvc.yaml
# Copied cypherpunk-remote-exec-w-psexesvc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\detect-cyzfc-activity (1).yaml
# Copied detect-cyzfc-activity (1).yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\detect-cyzfc-activity (2).yaml
# Copied detect-cyzfc-activity (2).yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\detect-cyzfc-activity (3).yaml
# Copied detect-cyzfc-activity (3).yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\detect-cyzfc-activity (4).yaml
# Copied detect-cyzfc-activity (4).yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied detect-cyzfc-activity (4).yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied detect-cyzfc-activity (4).yaml to files_parsed_by_nahed\DeviceEvents
# Copied detect-cyzfc-activity (4).yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Copied detect-cyzfc-activity (4).yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied detect-cyzfc-activity (4).yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\detect-cyzfc-activity.yaml
# Copied detect-cyzfc-activity.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied detect-cyzfc-activity.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied detect-cyzfc-activity.yaml to files_parsed_by_nahed\DeviceEvents
# Copied detect-cyzfc-activity.yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Copied detect-cyzfc-activity.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied detect-cyzfc-activity.yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\DofoilNameCoinServerTraffic.yaml
# Copied DofoilNameCoinServerTraffic.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\Dopplepaymer In-Memory Malware Implant.yaml
# Copied Dopplepaymer In-Memory Malware Implant.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Dragon Fly.yaml
# Copied Dragon Fly.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Elise backdoor.yaml
# Copied Elise backdoor.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Equation Group C2 Communication.yaml
# Copied Equation Group C2 Communication.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\fireeye-red-team-tools-CVEs [Nobelium].yaml
# Copied fireeye-red-team-tools-CVEs [Nobelium].yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilitiesKB
# Copied fireeye-red-team-tools-CVEs [Nobelium].yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilities
# Parsing YAML file: downloaded_files\Campaigns\fireeye-red-team-tools-HASHs [Nobelium].yaml
# Copied fireeye-red-team-tools-HASHs [Nobelium].yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied fireeye-red-team-tools-HASHs [Nobelium].yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\Hurricane Panda activity.yaml
# Copied Hurricane Panda activity.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Judgement Panda exfil activity.yaml
# Copied Judgement Panda exfil activity.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\known-affected-software-orion[Nobelium].yaml
# Copied known-affected-software-orion[Nobelium].yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilities
# Parsing YAML file: downloaded_files\Campaigns\launching-base64-powershell[Nobelium].yaml
# Copied launching-base64-powershell[Nobelium].yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\launching-cmd-echo[Nobelium].yaml
# Copied launching-cmd-echo[Nobelium].yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\locate-dll-created-locally[Nobelium].yaml
# Copied locate-dll-created-locally[Nobelium].yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\locate-dll-loaded-in-memory[Nobelium].yaml
# Copied locate-dll-loaded-in-memory[Nobelium].yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\MacOceanLotusBackdoor.yaml
# Copied MacOceanLotusBackdoor.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\MacOceanLotusDropper.yaml
# Copied MacOceanLotusDropper.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\OceanLotus registry activity.yaml
# Copied OceanLotus registry activity.yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Parsing YAML file: downloaded_files\Campaigns\oceanlotus-apt32-files.yaml
# Copied oceanlotus-apt32-files.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied oceanlotus-apt32-files.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\oceanlotus-apt32-network.yaml
# Copied oceanlotus-apt32-network.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\possible-affected-software-orion[Nobelium].yaml
# Copied possible-affected-software-orion[Nobelium].yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilities
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Alternate Data Streams use.yaml
# Copied Ransomware hits healthcare - Alternate Data Streams use.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Backup deletion.yaml
# Copied Ransomware hits healthcare - Backup deletion.yaml to files_parsed_by_nahed\AlertInfo
# Copied Ransomware hits healthcare - Backup deletion.yaml to files_parsed_by_nahed\AlertEvidence
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Cipher.exe tool deleting data.yaml
# Copied Ransomware hits healthcare - Cipher.exe tool deleting data.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Clearing of system logs.yaml
# Copied Ransomware hits healthcare - Clearing of system logs.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Possible compromised accounts.yaml
# Copied Ransomware hits healthcare - Possible compromised accounts.yaml to files_parsed_by_nahed\AlertInfo
# Copied Ransomware hits healthcare - Possible compromised accounts.yaml to files_parsed_by_nahed\AlertEvidence
# Copied Ransomware hits healthcare - Possible compromised accounts.yaml to files_parsed_by_nahed\DeviceLogonEvents
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Robbinhood activity.yaml
# Copied Ransomware hits healthcare - Robbinhood activity.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Turning off System Restore.yaml
# Copied Ransomware hits healthcare - Turning off System Restore.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Ransomware hits healthcare - Vulnerable Gigabyte drivers.yaml
# Copied Ransomware hits healthcare - Vulnerable Gigabyte drivers.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\redmenshen-bpfdoor-backdoor.yaml
# Copied redmenshen-bpfdoor-backdoor.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\robbinhood-driver.yaml
# Copied robbinhood-driver.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\robbinhood-evasion.yaml
# Copied robbinhood-evasion.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\snip3-aviation-targeting-emails.yaml
# Copied snip3-aviation-targeting-emails.yaml to files_parsed_by_nahed\EmailEvents
# Copied snip3-aviation-targeting-emails.yaml to files_parsed_by_nahed\EmailUrlInfo
# Parsing YAML file: downloaded_files\Campaigns\snip3-detectsanboxie-function-call.yaml
# Copied snip3-detectsanboxie-function-call.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\snip3-encoded-powershell-structure.yaml
# Copied snip3-encoded-powershell-structure.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\snip3-malicious-network-connectivity.yaml
# Copied snip3-malicious-network-connectivity.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\snip3-revengerat-c2-exfiltration.yaml
# Copied snip3-revengerat-c2-exfiltration.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\StarBlizzardDomainIOCsAug2022.yaml
# Copied StarBlizzardDomainIOCsAug2022.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\Threat actor Phosphorus masquerading as conference organizers (1).yaml
# Copied Threat actor Phosphorus masquerading as conference organizers (1).yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Campaigns\Threat actor Phosphorus masquerading as conference organizers (2).yaml
# Copied Threat actor Phosphorus masquerading as conference organizers (2).yaml to files_parsed_by_nahed\EmailPostDeliveryEvents
# Copied Threat actor Phosphorus masquerading as conference organizers (2).yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Campaigns\Threat actor Phosphorus masquerading as conference organizers.yaml
# Copied Threat actor Phosphorus masquerading as conference organizers.yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Campaigns\WastedLocker Downloader.yaml
# Copied WastedLocker Downloader.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Bazacall Emails.yaml
# Copied Bazacall Emails.yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Cobalt Strike Lateral Movement.yaml
# Copied Cobalt Strike Lateral Movement.yaml to files_parsed_by_nahed\AlertInfo
# Copied Cobalt Strike Lateral Movement.yaml to files_parsed_by_nahed\AlertEvidence
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Dropping payload via certutil.yaml
# Copied Dropping payload via certutil.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Excel file download domain pattern.yaml
# Copied Excel file download domain pattern.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Excel Macro Execution.yaml
# Copied Excel Macro Execution.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Malicious Excel Delivery.yaml
# Copied Malicious Excel Delivery.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\NTDS theft.yaml
# Copied NTDS theft.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\Renamed Rclone Exfil.yaml
# Copied Renamed Rclone Exfil.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazacall\RunDLL Suspicious Network Connection.yaml
# Copied RunDLL Suspicious Network Connection.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazarloader\Stolen Images Execution.yaml
# Copied Stolen Images Execution.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazarloader\Zip-Doc - Creation of JPG Payload File.yaml
# Copied Zip-Doc - Creation of JPG Payload File.yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Campaigns\Bazarloader\Zip-Doc - Word Launching MSHTA.yaml
# Copied Zip-Doc - Word Launching MSHTA.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\EUROPIUM\Identify EUROPIUM IOCs.yaml
# Copied Identify EUROPIUM IOCs.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\EUROPIUM\Identify Microsoft Defender Antivirus detection related to EUROPIUM.yaml
# Copied Identify Microsoft Defender Antivirus detection related to EUROPIUM.yaml to files_parsed_by_nahed\AlertEvidence
# Parsing YAML file: downloaded_files\Campaigns\EUROPIUM\Identify unusual identity additions related to EUROPIUM.yaml
# Copied Identify unusual identity additions related to EUROPIUM.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Jupyter-Solarmaker\deimos-component-execution.yaml
# Copied deimos-component-execution.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\Jupyter-Solarmaker\evasive-powershell-executions.yaml
# Copied evasive-powershell-executions.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Jupyter-Solarmaker\evasive-powershell-strings.yaml
# Copied evasive-powershell-strings.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Jupyter-Solarmaker\successive-tk-domain-calls.yaml
# Copied successive-tk-domain-calls.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\KNOTWEED\KNOTWEED-AVDetections.yaml
# Copied KNOTWEED-AVDetections.yaml to files_parsed_by_nahed\SecurityAlert (MDATP)
# Parsing YAML file: downloaded_files\Campaigns\KNOTWEED\KNOTWEED-COMRegistryKeyModifiedtoPointtoColorProfileFolder.yaml
# Copied KNOTWEED-COMRegistryKeyModifiedtoPointtoColorProfileFolder.yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Parsing YAML file: downloaded_files\Campaigns\KNOTWEED\KNOTWEED-DomainIOCsJuly2022.yaml
# Copied KNOTWEED-DomainIOCsJuly2022.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\KNOTWEED\KNOTWEED-DownloadingnewfileusingCurl.yaml
# Copied KNOTWEED-DownloadingnewfileusingCurl.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\KNOTWEED\KNOTWEED-FileHashIOCsJuly2022.yaml
# Copied KNOTWEED-FileHashIOCsJuly2022.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\KNOTWEED\KNOTWEED-PEFileDroppedinColorProfileFolder.yaml
# Copied KNOTWEED-PEFileDroppedinColorProfileFolder.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-competition-killer.yaml
# Copied LemonDuck-competition-killer.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-component-download-structure.yaml
# Copied LemonDuck-component-download-structure.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-component-names.yaml
# Copied LemonDuck-component-names.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-control-structure.yaml
# Copied LemonDuck-control-structure.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-defender-exclusions.yaml
# Copied LemonDuck-defender-exclusions.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-email-subjects.yaml
# Copied LemonDuck-email-subjects.yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-id-generation.yaml
# Copied LemonDuck-id-generation.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\LemonDuck\LemonDuck-registration-function.yaml
# Copied LemonDuck-registration-function.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Campaigns\Log4J\Alerts related to Log4j vulnerability.yaml
# Copied Alerts related to Log4j vulnerability.yaml to files_parsed_by_nahed\AlertInfo
# Parsing YAML file: downloaded_files\Campaigns\Log4J\Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# Copied Devices with Log4j vulnerability alerts and additional other alert related context.yaml to files_parsed_by_nahed\AlertInfo
# Copied Devices with Log4j vulnerability alerts and additional other alert related context.yaml to files_parsed_by_nahed\AlertEvidence
# Parsing YAML file: downloaded_files\Campaigns\Log4J\Suspicious JScript staging comment.yaml
# Copied Suspicious JScript staging comment.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Log4J\Suspicious PowerShell curl flags.yaml
# Copied Suspicious PowerShell curl flags.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Log4J\Suspicious process event creation from VMWare Horizon TomcatService.yaml
# Copied Suspicious process event creation from VMWare Horizon TomcatService.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Macaw Ransomware\Disable Controlled Folders.yaml
# Copied Disable Controlled Folders.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Macaw Ransomware\Imminent Ransomware.yaml
# Copied Imminent Ransomware.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Macaw Ransomware\Inhibit recovery by disabling tools and functionality.yaml
# Copied Inhibit recovery by disabling tools and functionality.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Macaw Ransomware\Mass account password change.yaml
# Copied Mass account password change.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Macaw Ransomware\PSExec Attrib commands.yaml
# Copied PSExec Attrib commands.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Macaw Ransomware\Use of MSBuild as LOLBin.yaml
# Copied Use of MSBuild as LOLBin.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Qakbot\Excel launching anomalous processes.yaml
# Copied Excel launching anomalous processes.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Qakbot\General attempts to access local email store.yaml
# Copied General attempts to access local email store.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\Qakbot\Qakbot Craigslist Domains.yaml
# Copied Qakbot Craigslist Domains.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\Qakbot\Qakbot email theft (1).yaml
# Copied Qakbot email theft (1).yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\Qakbot\Qakbot email theft.yaml
# Copied Qakbot email theft.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\Qakbot\Qakbot reconnaissance activities.yaml
# Copied Qakbot reconnaissance activities.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\StrRAT malware\StrRAT-AV-Discovery.yaml
# Copied StrRAT-AV-Discovery.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\StrRAT malware\StrRAT-Email-Delivery.yaml
# Copied StrRAT-Email-Delivery.yaml to files_parsed_by_nahed\EmailUrlInfo
# Parsing YAML file: downloaded_files\Campaigns\StrRAT malware\StrRAT-Malware-Persistence.yaml
# Copied StrRAT-Malware-Persistence.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Sysrv-botnet\app-armor-stopped.yaml
# Copied app-armor-stopped.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Sysrv-botnet\java-executing-cmd-to-run-powershell.yaml
# Copied java-executing-cmd-to-run-powershell.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Sysrv-botnet\kinsing-miner-download.yaml
# Copied kinsing-miner-download.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Sysrv-botnet\oracle-webLogic-executing-powershell.yaml
# Copied oracle-webLogic-executing-powershell.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied oracle-webLogic-executing-powershell.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\Sysrv-botnet\rce-on-vulnerable-server.yaml
# Copied rce-on-vulnerable-server.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\Sysrv-botnet\tomcat-8-executing-powershell.yaml
# Copied tomcat-8-executing-powershell.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Campaigns\ZLoader\Malicious bat file.yaml
# Copied Malicious bat file.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Campaigns\ZLoader\Payload Delivery.yaml
# Copied Payload Delivery.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Campaigns\ZLoader\Suspicious Registry Keys.yaml
# Copied Suspicious Registry Keys.yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Parsing YAML file: downloaded_files\Cloud Apps\aad-group-adds.yaml
# Copied aad-group-adds.yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Cloud Apps\aad-role-adds.yaml
# Copied aad-role-adds.yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Cloud Apps\file-download-events.yaml
# Copied file-download-events.yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Cloud Apps\mass-downloads.yaml
# Copied mass-downloads.yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Collection\Anomaly of MailItemAccess by Other Users Mailbox [Nobelium].yaml
# Copied Anomaly of MailItemAccess by Other Users Mailbox [Nobelium].yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Collection\HostExportingMailboxAndRemovingExport[Solarigate].yaml
# Copied HostExportingMailboxAndRemovingExport[Solarigate].yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Collection\MailItemsAccessedTimeSeries[Solarigate].yaml
# Copied MailItemsAccessedTimeSeries[Solarigate].yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Command and Control\c2-bluekeep.yaml
# Copied c2-bluekeep.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Command and Control\C2-NamedPipe.yaml
# Copied C2-NamedPipe.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Command and Control\check-for-shadowhammer-activity-download-domain.yaml
# Copied check-for-shadowhammer-activity-download-domain.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Command and Control\Connection to Rare DNS Hosts.yaml
# Copied Connection to Rare DNS Hosts.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Command and Control\Device network events w low count FQDN.yaml
# Copied Device network events w low count FQDN.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Command and Control\DNSPattern [Nobelium].yaml
# Copied DNSPattern [Nobelium].yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied DNSPattern [Nobelium].yaml to files_parsed_by_nahed\DeviceEvents
# Copied DNSPattern [Nobelium].yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Command and Control\EncodedDomainURL [Nobelium].yaml
# Copied EncodedDomainURL [Nobelium].yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied EncodedDomainURL [Nobelium].yaml to files_parsed_by_nahed\DeviceEvents
# Copied EncodedDomainURL [Nobelium].yaml to files_parsed_by_nahed\IdentityQueryEvents
# Copied EncodedDomainURL [Nobelium].yaml to files_parsed_by_nahed\AADSignInEventsBeta
# Parsing YAML file: downloaded_files\Command and Control\python-use-by-ransomware-macos.yaml
# Copied python-use-by-ransomware-macos.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied python-use-by-ransomware-macos.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Command and Control\recon-with-rundll.yaml
# Copied recon-with-rundll.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Command and Control\reverse-shell-ransomware-macos.yaml
# Copied reverse-shell-ransomware-macos.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied reverse-shell-ransomware-macos.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Command and Control\Tor.yaml
# Copied Tor.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Credential Access\Active Directory Sensitive Group Modifications.yaml
# Copied Active Directory Sensitive Group Modifications.yaml to files_parsed_by_nahed\IdentityDirectoryEvents
# Parsing YAML file: downloaded_files\Credential Access\cobalt-strike.yaml
# Copied cobalt-strike.yaml to files_parsed_by_nahed\AlertInfo
# Copied cobalt-strike.yaml to files_parsed_by_nahed\AlertEvidence
# Copied cobalt-strike.yaml to files_parsed_by_nahed\DeviceLogonEvents
# Parsing YAML file: downloaded_files\Credential Access\doppelpaymer-procdump.yaml
# Copied doppelpaymer-procdump.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Credential Access\identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# Copied identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml to files_parsed_by_nahed\AlertInfo
# Copied identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml to files_parsed_by_nahed\AlertEvidence
# Copied identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml to files_parsed_by_nahed\DeviceLogonEvents
# Parsing YAML file: downloaded_files\Credential Access\lazagne.yaml
# Copied lazagne.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Credential Access\logon-attempts-after-malicious-email.yaml
# Copied logon-attempts-after-malicious-email.yaml to files_parsed_by_nahed\EmailEvents
# Copied logon-attempts-after-malicious-email.yaml to files_parsed_by_nahed\IdentityLogonEvents
# Parsing YAML file: downloaded_files\Credential Access\Private Key Files.yaml
# Copied Private Key Files.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Credential Access\procdump-lsass-credentials.yaml
# Copied procdump-lsass-credentials.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Credential Access\wadhrama-credential-dump.yaml
# Copied wadhrama-credential-dump.yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Parsing YAML file: downloaded_files\Credential Access\wdigest-caching.yaml
# Copied wdigest-caching.yaml to files_parsed_by_nahed\DeviceRegistryEvents
# Copied wdigest-caching.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\ADFSDomainTrustMods[Nobelium].yaml
# Copied ADFSDomainTrustMods[Nobelium].yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Defense evasion\alt-data-streams.yaml
# Copied alt-data-streams.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\clear-system-logs.yaml
# Copied clear-system-logs.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\deleting-data-w-cipher-tool.yaml
# Copied deleting-data-w-cipher-tool.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\Discovering potentially tampered devices [Nobelium].yaml
# Copied Discovering potentially tampered devices [Nobelium].yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied Discovering potentially tampered devices [Nobelium].yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\doppelpaymer-stop-services.yaml
# Copied doppelpaymer-stop-services.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\hiding-java-class-file.yaml
# Copied hiding-java-class-file.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied hiding-java-class-file.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\locate-files-possibly-signed-by-fraudulent-ecc-certificates.yaml
# Copied locate-files-possibly-signed-by-fraudulent-ecc-certificates.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\Defense evasion\MailPermissionsAddedToApplication[Nobelium].yaml
# Copied MailPermissionsAddedToApplication[Nobelium].yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Defense evasion\PotentialMicrosoftDefenderTampering[Solarigate].yaml
# Copied PotentialMicrosoftDefenderTampering[Solarigate].yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\qakbot-campaign-process-injection.yaml
# Copied qakbot-campaign-process-injection.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\qakbot-campaign-self-deletion.yaml
# Copied qakbot-campaign-self-deletion.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Defense evasion\regsvr32-rundll32-image-loads-abnormal-extension.yaml
# Copied regsvr32-rundll32-image-loads-abnormal-extension.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied regsvr32-rundll32-image-loads-abnormal-extension.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Defense evasion\regsvr32-rundll32-image-loads-from-abnormal-locations.yaml
# Copied regsvr32-rundll32-image-loads-from-abnormal-locations.yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Copied regsvr32-rundll32-image-loads-from-abnormal-locations.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Defense evasion\regsvr32-rundll32-with-anomalous-parent-process.yaml
# Copied regsvr32-rundll32-with-anomalous-parent-process.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied regsvr32-rundll32-with-anomalous-parent-process.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Defense evasion\UpdateStsRefreshToken[Solorigate].yaml
# Copied UpdateStsRefreshToken[Solorigate].yaml to files_parsed_by_nahed\CloudAppEvents
# Parsing YAML file: downloaded_files\Delivery\detect-jscript-file-creation.yaml
# Copied detect-jscript-file-creation.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Delivery\Doc attachment with link to download.yaml
# Copied Doc attachment with link to download.yaml to files_parsed_by_nahed\DeviceEvents
# Copied Doc attachment with link to download.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Delivery\Dropbox downloads linked from other site.yaml
# Copied Dropbox downloads linked from other site.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Delivery\Email link + download + SmartScreen warning.yaml
# Copied Email link + download + SmartScreen warning.yaml to files_parsed_by_nahed\DeviceEvents
# Copied Email link + download + SmartScreen warning.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Delivery\Gootkit-malware.yaml
# Copied Gootkit-malware.yaml to files_parsed_by_nahed\AlertInfo
# Copied Gootkit-malware.yaml to files_parsed_by_nahed\AlertEvidence
# Copied Gootkit-malware.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Delivery\Open email link.yaml
# Copied Open email link.yaml to files_parsed_by_nahed\DeviceEvents
# Copied Open email link.yaml to files_parsed_by_nahed\AlertInfo
# Copied Open email link.yaml to files_parsed_by_nahed\AlertEvidence
# Parsing YAML file: downloaded_files\Delivery\Pivot from detections to related downloads.yaml
# Copied Pivot from detections to related downloads.yaml to files_parsed_by_nahed\DeviceEvents
# Copied Pivot from detections to related downloads.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Delivery\powercat-download.yaml
# Copied powercat-download.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Delivery\Qakbot Craigslist Domains.yaml
# Copied Qakbot Craigslist Domains.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Device Inventory\Anomalous Device Models.yaml
# Copied Anomalous Device Models.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Can Be Onboarded Devices.yaml
# Copied Can Be Onboarded Devices.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Commonality of Operating Systems.yaml
# Copied Commonality of Operating Systems.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Count and Percentage of DeviceType.yaml
# Copied Count and Percentage of DeviceType.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Devices By Specific DeviceType and DeviceSubtype.yaml
# Copied Devices By Specific DeviceType and DeviceSubtype.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Devices In Subnet - IPAddressV4.yaml
# Copied Devices In Subnet - IPAddressV4.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Devices In Subnet - IPAddressV6.yaml
# Copied Devices In Subnet - IPAddressV6.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Find Software By Name and Version.yaml
# Copied Find Software By Name and Version.yaml to files_parsed_by_nahed\DeviceTvmSoftwareInventory
# Parsing YAML file: downloaded_files\Device Inventory\Most Common Services.yaml
# Copied Most Common Services.yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilities
# Parsing YAML file: downloaded_files\Device Inventory\NotOnboarded Devices by DeviceName Prefix.yaml
# Copied NotOnboarded Devices by DeviceName Prefix.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\NotOnboarded Devices by DeviceName Suffix.yaml
# Copied NotOnboarded Devices by DeviceName Suffix.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Device Inventory\Seen Connected Networks.yaml
# Copied Seen Connected Networks.yaml to files_parsed_by_nahed\DeviceNetworkInfo
# Parsing YAML file: downloaded_files\Device Inventory\Seen IPv4 Network Subnets.yaml
# Copied Seen IPv4 Network Subnets.yaml to files_parsed_by_nahed\DeviceNetworkInfo
# Parsing YAML file: downloaded_files\Device Inventory\Seen IPv6 Network Subnets.yaml
# Copied Seen IPv6 Network Subnets.yaml to files_parsed_by_nahed\DeviceNetworkInfo
# Parsing YAML file: downloaded_files\Discovery\ConnectedNetworkDeviceDiscovery.yaml
# Copied ConnectedNetworkDeviceDiscovery.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Discovery\detect-nbtscan-activity.yaml
# Copied detect-nbtscan-activity.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied detect-nbtscan-activity.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Discovery\Detect-Not-Active-AD-User-Accounts.yaml
# Copied Detect-Not-Active-AD-User-Accounts.yaml to files_parsed_by_nahed\IdentityLogonEvents
# Parsing YAML file: downloaded_files\Discovery\detect-suspicious-commands-initiated-by-web-server-processes.yaml
# Copied detect-suspicious-commands-initiated-by-web-server-processes.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Discovery\DetectTorRelayConnectivity.yaml
# Copied DetectTorRelayConnectivity.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied DetectTorRelayConnectivity.yaml to files_parsed_by_nahed\DeviceInfo
# Parsing YAML file: downloaded_files\Discovery\DetectTorrentUse.yaml
# Copied DetectTorrentUse.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Discovery\Discover hosts doing possible network scans.yaml
# Copied Discover hosts doing possible network scans.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Discovery\doppelpaymer.yaml
# Copied doppelpaymer.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Discovery\Enumeration of users & groups for lateral movement.yaml
# Copied Enumeration of users & groups for lateral movement.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Discovery\MultipleLdaps.yaml
# Copied MultipleLdaps.yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Discovery\MultipleSensitiveLdaps.yaml
# Copied MultipleSensitiveLdaps.yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Discovery\PasswordSearch.yaml
# Copied PasswordSearch.yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Discovery\qakbot-campaign-esentutl.yaml
# Copied qakbot-campaign-esentutl.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Discovery\qakbot-campaign-outlook.yaml
# Copied qakbot-campaign-outlook.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Discovery\Roasting.yaml
# Copied Roasting.yaml to files_parsed_by_nahed\IdentityQueryEvents
# Copied Roasting.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Discovery\SensitiveLdaps.yaml
# Copied SensitiveLdaps.yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Discovery\SMB shares discovery.yaml
# Copied SMB shares discovery.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Discovery\SuspiciousEnumerationUsingAdfind[Nobelium].yaml
# Copied SuspiciousEnumerationUsingAdfind[Nobelium].yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Discovery\URL Detection.yaml
# Copied URL Detection.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Discovery\VulnComputers.yaml
# Copied VulnComputers.yaml to files_parsed_by_nahed\IdentityQueryEvents
# Parsing YAML file: downloaded_files\Email Queries\Appspot Phishing Abuse.yaml
# Copied Appspot Phishing Abuse.yaml to files_parsed_by_nahed\EmailUrlInfo
# Copied Appspot Phishing Abuse.yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Email Queries\Email-RemediationAction-List.yaml
# Copied Email-RemediationAction-List.yaml to files_parsed_by_nahed\EmailEvents
# Parsing YAML file: downloaded_files\Email Queries\JNLP-File-Attachment.yaml
# Copied JNLP-File-Attachment.yaml to files_parsed_by_nahed\EmailAttachmentInfo
# Parsing YAML file: downloaded_files\Email Queries\PhishingEmailUrlRedirector (1).yaml
# Copied PhishingEmailUrlRedirector (1).yaml to files_parsed_by_nahed\EmailUrlInfo
# Parsing YAML file: downloaded_files\Email Queries\PhishingEmailUrlRedirector.yaml
# Copied PhishingEmailUrlRedirector.yaml to files_parsed_by_nahed\EmailUrlInfo
# Parsing YAML file: downloaded_files\Email Queries\referral-phish-emails.yaml
# Copied referral-phish-emails.yaml to files_parsed_by_nahed\EmailEvents
# Copied referral-phish-emails.yaml to files_parsed_by_nahed\EmailUrlInfo
# Parsing YAML file: downloaded_files\Execution\anomalous-payload-delivered-from-iso-file.yaml
# Copied anomalous-payload-delivered-from-iso-file.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied anomalous-payload-delivered-from-iso-file.yaml to files_parsed_by_nahed\DeviceEvents
# Parsing YAML file: downloaded_files\Execution\Base64 Detector and Decoder.yaml
# Copied Base64 Detector and Decoder.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\Base64encodePEFile.yaml
# Copied Base64encodePEFile.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\Bitsadmin Activity.yaml
# Copied Bitsadmin Activity.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\check-for-shadowhammer-activity-implant.yaml
# Copied check-for-shadowhammer-activity-implant.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Copied check-for-shadowhammer-activity-implant.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Copied check-for-shadowhammer-activity-implant.yaml to files_parsed_by_nahed\DeviceFileEvents
# Copied check-for-shadowhammer-activity-implant.yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Execution\Detect Encoded Powershell.yaml
# Copied Detect Encoded Powershell.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\Detect PowerShell v2 Downgrade.yaml
# Copied Detect PowerShell v2 Downgrade.yaml to files_parsed_by_nahed\DeviceImageLoadEvents
# Parsing YAML file: downloaded_files\Execution\detect-anomalous-process-trees.yaml
# Copied detect-anomalous-process-trees.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-bluekeep-related-mining.yaml
# Copied detect-bluekeep-related-mining.yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\Execution\detect-doublepulsar-execution.yaml
# Copied detect-doublepulsar-execution.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-exploitation-of-cve-2018-8653.yaml
# Copied detect-exploitation-of-cve-2018-8653.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-malicious-rar-extraction.yaml
# Copied detect-malicious-rar-extraction.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-malicious-use-of-msiexec-mimikatz.yaml
# Copied detect-malicious-use-of-msiexec-mimikatz.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-malicious-use-of-msiexec-msiexec.yaml
# Copied detect-malicious-use-of-msiexec-msiexec.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-malicious-use-of-msiexec-powershell.yaml
# Copied detect-malicious-use-of-msiexec-powershell.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-office-apps-spawn-msdt-CVE-2022-30190.yaml
# Copied detect-office-apps-spawn-msdt-CVE-2022-30190.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-office-products-spawning-wmic.yaml
# Copied detect-office-products-spawning-wmic.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-potential-kerberoast-activities.yaml
# Copied detect-potential-kerberoast-activities.yaml to files_parsed_by_nahed\IdentityLogonEvents
# Parsing YAML file: downloaded_files\Execution\detect-suspicious-mshta-usage.yaml
# Copied detect-suspicious-mshta-usage.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\detect-web-server-exploit-doublepulsar.yaml
# Copied detect-web-server-exploit-doublepulsar.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\Execution\exchange-iis-worker-dropping-webshell.yaml
# ...
# Copied rmm_Naverisk_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_NetSupport_createproc.yaml
# Copied rmm_NetSupport_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_NetSupport_filesig.yaml
# Copied rmm_NetSupport_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_NetSupport_netconn.yaml
# Copied rmm_NetSupport_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_NinjaRMM_createproc.yaml
# Copied rmm_NinjaRMM_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_NinjaRMM_filesig.yaml
# Copied rmm_NinjaRMM_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_NinjaRMM_netconn.yaml
# Copied rmm_NinjaRMM_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_OptiTune_createproc.yaml
# Copied rmm_OptiTune_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_OptiTune_filesig.yaml
# Copied rmm_OptiTune_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_OptiTune_netconn.yaml
# Copied rmm_OptiTune_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Panorama9_createproc.yaml
# Copied rmm_Panorama9_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Panorama9_filesig.yaml
# Copied rmm_Panorama9_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Panorama9_netconn.yaml
# Copied rmm_Panorama9_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_parsec.app_createproc.yaml
# Copied rmm_parsec.app_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_parsec.app_filesig.yaml
# Copied rmm_parsec.app_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_parsec.app_netconn.yaml
# Copied rmm_parsec.app_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_PcVisit_createproc.yaml
# Copied rmm_PcVisit_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_PcVisit_filesig.yaml
# Copied rmm_PcVisit_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_PcVisit_netconn.yaml
# Copied rmm_PcVisit_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_PDQ_createproc.yaml
# Copied rmm_PDQ_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_PDQ_filesig.yaml
# Copied rmm_PDQ_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_PDQ_netconn.yaml
# Copied rmm_PDQ_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Pulseway_createproc.yaml
# Copied rmm_Pulseway_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Pulseway_filesig.yaml
# Copied rmm_Pulseway_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Pulseway_netconn.yaml
# Copied rmm_Pulseway_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RealVNC_createproc.yaml
# Copied rmm_RealVNC_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RealVNC_filesig.yaml
# Copied rmm_RealVNC_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RealVNC_netconn.yaml
# Copied rmm_RealVNC_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemoteDesktopPlus_createproc.yaml
# Copied rmm_RemoteDesktopPlus_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemoteDesktopPlus_netconn.yaml
# Copied rmm_RemoteDesktopPlus_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemotePC_createproc.yaml
# Copied rmm_RemotePC_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemotePC_filesig.yaml
# Copied rmm_RemotePC_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemotePC_netconn.yaml
# Copied rmm_RemotePC_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemoteUtilities_createproc.yaml
# Copied rmm_RemoteUtilities_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemoteUtilities_filesig.yaml
# Copied rmm_RemoteUtilities_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RemoteUtilities_netconn.yaml
# Copied rmm_RemoteUtilities_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RPort_createproc.yaml
# Copied rmm_RPort_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RPort_netconn.yaml
# Copied rmm_RPort_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RustDesk_createproc.yaml
# Copied rmm_RustDesk_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_RustDesk_netconn.yaml
# Copied rmm_RustDesk_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ScreenMeet_createproc.yaml
# Copied rmm_ScreenMeet_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ScreenMeet_filesig.yaml
# Copied rmm_ScreenMeet_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ScreenMeet_netconn.yaml
# Copied rmm_ScreenMeet_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ServerEye_createproc.yaml
# Copied rmm_ServerEye_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ServerEye_filesig.yaml
# Copied rmm_ServerEye_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ServerEye_netconn.yaml
# Copied rmm_ServerEye_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ShowMyPC_createproc.yaml
# Copied rmm_ShowMyPC_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ShowMyPC_filesig.yaml
# Copied rmm_ShowMyPC_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ShowMyPC_netconn.yaml
# Copied rmm_ShowMyPC_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SimpleHelp_createproc.yaml
# Copied rmm_SimpleHelp_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SimpleHelp_filesig.yaml
# Copied rmm_SimpleHelp_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SimpleHelp_netconn.yaml
# Copied rmm_SimpleHelp_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Splashtop_createproc.yaml
# Copied rmm_Splashtop_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Splashtop_filesig.yaml
# Copied rmm_Splashtop_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_Splashtop_netconn.yaml
# Copied rmm_Splashtop_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SupRemo_createproc.yaml
# Copied rmm_SupRemo_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SupRemo_filesig.yaml
# Copied rmm_SupRemo_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SupRemo_netconn.yaml
# Copied rmm_SupRemo_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SyncroMSP_createproc.yaml
# Copied rmm_SyncroMSP_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SyncroMSP_filesig.yaml
# Copied rmm_SyncroMSP_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_SyncroMSP_netconn.yaml
# Copied rmm_SyncroMSP_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TacticalRMM_createproc.yaml
# Copied rmm_TacticalRMM_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TacticalRMM_filesig.yaml
# Copied rmm_TacticalRMM_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TacticalRMM_netconn.yaml
# Copied rmm_TacticalRMM_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TeamViewer_createproc.yaml
# Copied rmm_TeamViewer_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TeamViewer_filesig.yaml
# Copied rmm_TeamViewer_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TeamViewer_netconn.yaml
# Copied rmm_TeamViewer_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TigerVNC_createproc.yaml
# Copied rmm_TigerVNC_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TigerVNC_netconn.yaml
# Copied rmm_TigerVNC_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TightVNC_createproc.yaml
# Copied rmm_TightVNC_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TightVNC_filesig.yaml
# Copied rmm_TightVNC_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_TightVNC_netconn.yaml
# Copied rmm_TightVNC_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_UltraViewer_createproc.yaml
# Copied rmm_UltraViewer_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_UltraViewer_filesig.yaml
# Copied rmm_UltraViewer_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_UltraViewer_netconn.yaml
# Copied rmm_UltraViewer_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_XMReality_createproc.yaml
# Copied rmm_XMReality_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_XMReality_filesig.yaml
# Copied rmm_XMReality_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_XMReality_netconn.yaml
# Copied rmm_XMReality_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ZohoAssist_createproc.yaml
# Copied rmm_ZohoAssist_createproc.yaml to files_parsed_by_nahed\DeviceProcessEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ZohoAssist_filesig.yaml
# Copied rmm_ZohoAssist_filesig.yaml to files_parsed_by_nahed\DeviceFileCertificateInfo
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm_ZohoAssist_netconn.yaml
# Copied rmm_ZohoAssist_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\RemoteManagementMonitoring\rmm__all_netconn.yaml
# Copied rmm__all_netconn.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Troubleshooting\Connectivity Failures by Device.yaml
# Copied Connectivity Failures by Device.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\Troubleshooting\Connectivity Failures by Domain.yaml
# Copied Connectivity Failures by Domain.yaml to files_parsed_by_nahed\DeviceNetworkEvents
# Parsing YAML file: downloaded_files\TVM\Detect_CISA_Alert_AA22-117A2021_Top_Routinely_Exploited_Vulnerabilities.yaml
# Copied Detect_CISA_Alert_AA22-117A2021_Top_Routinely_Exploited_Vulnerabilities.yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilitiesKB
# Parsing YAML file: downloaded_files\TVM\devices_with_vuln_and_users_received_payload (1).yaml
# Copied devices_with_vuln_and_users_received_payload (1).yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilities
# Copied devices_with_vuln_and_users_received_payload (1).yaml to files_parsed_by_nahed\DeviceFileEvents
# Parsing YAML file: downloaded_files\TVM\devices_with_vuln_and_users_received_payload.yaml
# Copied devices_with_vuln_and_users_received_payload.yaml to files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilities
# Copied devices_with_vuln_and_users_received_payload.yaml to files_parsed_by_nahed\DeviceInfo
# Copied devices_with_vuln_and_users_received_payload.yaml to files_parsed_by_nahed\IdentityInfo
# Copied devices_with_vuln_and_users_received_payload.yaml to files_parsed_by_nahed\EmailAttachmentInfo
# Parsing YAML file: downloaded_files\TVM\Microsoft Defender Anti virus Engine details.yaml
# Parsing YAML file: downloaded_files\TVM\Microsoft Defender Anti virus Platform details.yaml
# Parsing YAML file: downloaded_files\TVM\Microsoft Defender Anti virus Security Intelligence details.yaml
# Parsing YAML file: downloaded_files\TVM\Microsoft Defender AV details.yaml
# Parsing YAML file: downloaded_files\TVM\Microsoft Defender AV mode device count.yaml

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\ichrak\desktop\project-pfe\lib\site-packages (4.6.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\ichrak\desktop\project-pfe\lib\site-packages (from pymongo) (2.6.1)
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['myGithubBase']  # Replace with your MongoDB database name
collection = db['threadCollection']  # Replace with your MongoDB collection name

# %%
import os
import yaml

def store_yaml_files_in_mongodb(directory_path):
    for root, dirs, files in os.walk(directory_path):
        for file_name in files:
            if file_name.endswith(".yaml"):
                file_path = os.path.join(root, file_name)

                print(f"Storing YAML file in MongoDB: {file_path}")

                with open(file_path, 'r', encoding='utf-8') as file:
                    try:
                        yaml_data = yaml.safe_load(file)

                        # Insert the YAML data into MongoDB
                        collection.insert_one(yaml_data)

                        print(f"YAML data stored in MongoDB: {file_path}")

                    except yaml.YAMLError as e:
                        print(f"Error parsing YAML file {file_path}: {e}")

# Path to the directory where YAML files are organized
organized_directory = 'files_parsed_by_nahed'

# Store YAML files in MongoDB
store_yaml_files_in_mongodb(organized_directory)

# Close MongoDB connection
client.close()
# Out:
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\EncodedDomainURL [Nobelium].yaml
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[6], line 28
#      25 organized_directory = 'files_parsed_by_nahed'
#      27 # Store YAML files in MongoDB
# ---> 28 store_yaml_files_in_mongodb(organized_directory)
#      30 # Close MongoDB connection
#      31 client.close()
#
# Cell In[6], line 17, in store_yaml_files_in_mongodb(directory_path)
#      14     yaml_data = yaml.safe_load(file)
#      16     # Insert the YAML data into MongoDB
# ---> 17     collection.insert_one(yaml_data)
#      19     print(f"YAML data stored in MongoDB: {file_path}")
#      21 except yaml.YAMLError as e:
#
# File C:\Python312\Lib\site-packages\pymongo\collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File C:\Python312\Lib\site-packages\pymongo\collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File C:\Python312\Lib\site-packages\pymongo\mongo_client.py:1522, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1502 def _retryable_write(
#    1503     self,
#    1504     retryable: bool,
#    (...)
#    1507     bulk: Optional[_Bulk] = None,
#    1508 ) -> T:
#    1509     """Execute an operation with consecutive retries if possible
#    1510
#    1511     Returns func()'s return value on success. On error retries the same
#    (...)
#    1520       - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521     """
# -> 1522     with self._tmp_session(session) as s:
#    1523         return self._retry_with_session(retryable, func, s, bulk)
#
# File C:\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File C:\Python312\Lib\site-packages\pymongo\mongo_client.py:1840, in MongoClient._tmp_session(self, session, close)
#    1837     yield session
#    1838     return
# -> 1840 s = self._ensure_session(session)
#    1841 if s:
#    1842     try:
#
# File C:\Python312\Lib\site-packages\pymongo\mongo_client.py:1823, in MongoClient._ensure_session(self, session)
#    1818     return session
#    1820 try:
#    1821     # Don't make implicit sessions causally consistent. Applications
#    1822     # should always opt-in.
# -> 1823     return self.__start_session(True, causal_consistency=False)
#    1824 except (ConfigurationError, InvalidOperation):
#    1825     # Sessions not supported.
#    1826     return None
#
# File C:\Python312\Lib\site-packages\pymongo\mongo_client.py:1766, in MongoClient.__start_session(self, implicit, **kwargs)
#    1763 def __start_session(self, implicit: bool, **kwargs: Any) -> ClientSession:
#    1764     # Raises ConfigurationError if sessions are not supported.
#    1765     if implicit:
# -> 1766         self._topology._check_implicit_session_support()
#    1767         server_session: Union[_EmptyServerSession, _ServerSession] = _EmptyServerSession()
#    1768     else:
#
# File C:\Python312\Lib\site-packages\pymongo\topology.py:573, in Topology._check_implicit_session_support(self)
#     571 def _check_implicit_session_support(self) -> None:
#     572     with self._lock:
# --> 573         self._check_session_support()
#
# File C:\Python312\Lib\site-packages\pymongo\topology.py:589, in Topology._check_session_support(self)
#     585         self._select_servers_loop(
#     586             any_server_selector, self.get_server_selection_timeout(), None
#     587         )
#     588 elif not self._description.readable_servers:
# --> 589     self._select_servers_loop(
#     590         readable_server_selector, self.get_server_selection_timeout(), None
#     591     )
#     593 session_timeout = self._description.logical_session_timeout_minutes
#     594 if session_timeout is None:
#
# File C:\Python312\Lib\site-packages\pymongo\topology.py:259, in Topology._select_servers_loop(self, selector, timeout, address)
#     256 while not server_descriptions:
#     257     # No suitable servers.
#     258     if timeout == 0 or now > end_time:
# --> 259         raise ServerSelectionTimeoutError(
#     260             f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     261         )
#     263     self._ensure_opened()
#     264     self._request_check_all()
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65defec2d0bbced38d10c446, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
import os
import yaml
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['githubbase2']  # Replace with your MongoDB database name

def store_yaml_files_in_mongodb(directory_path):
    for root, dirs, files in os.walk(directory_path):
        for file_name in files:
            if file_name.endswith(".yaml"):
                file_path = os.path.join(root, file_name)

                print(f"Storing YAML file in MongoDB: {file_path}")

                with open(file_path, 'r', encoding='utf-8') as file:
                    try:
                        yaml_data = yaml.safe_load(file)

                        # Extract data type from the file path (assumes subdirectories represent data types)
                        data_type = os.path.relpath(root, directory_path)

                        # Create a collection for the data type if it doesn't exist
                        collection_name = f'{data_type}_collection'
                        collection = db[collection_name]

                        # Insert the YAML data into the corresponding collection
                        collection.insert_one(yaml_data)

                        print(f"YAML data stored in MongoDB collection {collection_name}: {file_path}")

                    except yaml.YAMLError as e:
                        print(f"Error parsing YAML file {file_path}: {e}")

# Path to the directory where YAML files are organized
organized_directory = 'files_parsed_by_nahed'

# Store YAML files in MongoDB
store_yaml_files_in_mongodb(organized_directory)

# Close MongoDB connection
client.close()
# Out:
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\EncodedDomainURL [Nobelium].yaml
# YAML data stored in MongoDB collection AADSignInEventsBeta_collection: files_parsed_by_nahed\AADSignInEventsBeta\EncodedDomainURL [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\riskySignInToDeviceRegistration.yaml
# YAML data stored in MongoDB collection AADSignInEventsBeta_collection: files_parsed_by_nahed\AADSignInEventsBeta\riskySignInToDeviceRegistration.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\riskySignInToElevateAccess.yaml
# YAML data stored in MongoDB collection AADSignInEventsBeta_collection: files_parsed_by_nahed\AADSignInEventsBeta\riskySignInToElevateAccess.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\riskySignInToNewMFAMethod.yaml
# YAML data stored in MongoDB collection AADSignInEventsBeta_collection: files_parsed_by_nahed\AADSignInEventsBeta\riskySignInToNewMFAMethod.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\unusual-volume-of-file-deletion.yaml
# YAML data stored in MongoDB collection AADSignInEventsBeta_collection: files_parsed_by_nahed\AADSignInEventsBeta\unusual-volume-of-file-deletion.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSignInEventsBeta\unusual-volume-of-file-sharing.yaml
# YAML data stored in MongoDB collection AADSignInEventsBeta_collection: files_parsed_by_nahed\AADSignInEventsBeta\unusual-volume-of-file-sharing.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AADSpnSignInEventsBeta\AddedCredentialFromContryXAndSigninFromCountryY.yaml
# YAML data stored in MongoDB collection AADSpnSignInEventsBeta_collection: files_parsed_by_nahed\AADSpnSignInEventsBeta\AddedCredentialFromContryXAndSigninFromCountryY.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Alert Events from Internal IP Address.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Alert Events from Internal IP Address.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Antivirus detections (1).yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Antivirus detections (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Baseline Comparison.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Baseline Comparison.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Cobalt Strike Lateral Movement.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Cobalt Strike Lateral Movement.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\cobalt-strike.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\cobalt-strike.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Distribution from remote location.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Distribution from remote location.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Events surrounding alert (1).yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Events surrounding alert (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Events surrounding alert (3).yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Events surrounding alert (3).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\ExploitGuardBlockOfficeChildProcess (1).yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\ExploitGuardBlockOfficeChildProcess (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\ExploitGuardBlockOfficeChildProcess (3).yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\ExploitGuardBlockOfficeChildProcess (3).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\File Backup Deletion Alerts.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\File Backup Deletion Alerts.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Gootkit File Delivery.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Gootkit File Delivery.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Gootkit-malware.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Gootkit-malware.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Identify Microsoft Defender Antivirus detection related to EUROPIUM.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Identify Microsoft Defender Antivirus detection related to EUROPIUM.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\ImpersonatedUserFootprint.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\ImpersonatedUserFootprint.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Open email link.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Open email link.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Potential ransomware activity related to Cobalt Strike.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Potential ransomware activity related to Cobalt Strike.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Ransomware hits healthcare - Backup deletion.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Ransomware hits healthcare - Backup deletion.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\Ransomware hits healthcare - Possible compromised accounts.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\Ransomware hits healthcare - Possible compromised accounts.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertEvidence\SuspiciousUrlClicked.yaml
# YAML data stored in MongoDB collection AlertEvidence_collection: files_parsed_by_nahed\AlertEvidence\SuspiciousUrlClicked.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Alert Events from Internal IP Address.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Alert Events from Internal IP Address.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Alerts related to Log4j vulnerability.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Alerts related to Log4j vulnerability.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Antivirus detections (1).yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Antivirus detections (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\backup-deletion.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\backup-deletion.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Baseline Comparison.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Baseline Comparison.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Cobalt Strike Lateral Movement.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Cobalt Strike Lateral Movement.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\cobalt-strike.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\cobalt-strike.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Devices with Log4j vulnerability alerts and additional other alert related context.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Distribution from remote location.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Distribution from remote location.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Events surrounding alert (1).yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Events surrounding alert (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Events surrounding alert (3).yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Events surrounding alert (3).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\ExploitGuardBlockOfficeChildProcess (1).yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\ExploitGuardBlockOfficeChildProcess (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\ExploitGuardBlockOfficeChildProcess (3).yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\ExploitGuardBlockOfficeChildProcess (3).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\File Backup Deletion Alerts.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\File Backup Deletion Alerts.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Gootkit File Delivery.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Gootkit File Delivery.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Gootkit-malware.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Gootkit-malware.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\identify-accounts-logged-on-to-endpoints-affected-by-cobalt-strike.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\ImpersonatedUserFootprint.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\ImpersonatedUserFootprint.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Open email link.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Open email link.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Potential ransomware activity related to Cobalt Strike.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Potential ransomware activity related to Cobalt Strike.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Ransomware hits healthcare - Backup deletion.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Ransomware hits healthcare - Backup deletion.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Ransomware hits healthcare - Possible compromised accounts.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Ransomware hits healthcare - Possible compromised accounts.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\Sticky Keys.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\Sticky Keys.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\AlertInfo\SuspiciousUrlClicked.yaml
# YAML data stored in MongoDB collection AlertInfo_collection: files_parsed_by_nahed\AlertInfo\SuspiciousUrlClicked.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\aad-group-adds.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\aad-group-adds.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\aad-role-adds.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\aad-role-adds.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\Add uncommon credential type to application [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\Add uncommon credential type to application [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\AddedCredentialFromContryXAndSigninFromCountryY.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\AddedCredentialFromContryXAndSigninFromCountryY.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\ADFSDomainTrustMods[Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\ADFSDomainTrustMods[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\Anomaly of MailItemAccess by GraphAPI [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\Anomaly of MailItemAccess by GraphAPI [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\Anomaly of MailItemAccess by Other Users Mailbox [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\Anomaly of MailItemAccess by Other Users Mailbox [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\codeRepoExfil.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\codeRepoExfil.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\CredentialsAddAfterAdminConsentedToApp[Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\CredentialsAddAfterAdminConsentedToApp[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\file-download-events.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\file-download-events.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\MailItemsAccessed Throttling [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\MailItemsAccessed Throttling [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\MailItemsAccessedTimeSeries[Solarigate].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\MailItemsAccessedTimeSeries[Solarigate].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\MailPermissionsAddedToApplication[Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\MailPermissionsAddedToApplication[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\mass-downloads.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\mass-downloads.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\multipleAADAdminsRemovals.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\multipleAADAdminsRemovals.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\NewAppOrServicePrincipalCredential[Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\NewAppOrServicePrincipalCredential[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\OAuth Apps accessing user mail via GraphAPI [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\OAuth Apps accessing user mail via GraphAPI [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\OAuth Apps reading mail both via GraphAPI and directly [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\OAuth Apps reading mail both via GraphAPI and directly [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\OAuth Apps reading mail via GraphAPI anomaly [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\OAuth Apps reading mail via GraphAPI anomaly [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\riskySignInToDeviceRegistration.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\riskySignInToDeviceRegistration.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\riskySignInToElevateAccess.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\riskySignInToElevateAccess.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\riskySignInToNewMFAMethod.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\riskySignInToNewMFAMethod.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\ServicePrincipalAddedToRole [Nobelium].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\ServicePrincipalAddedToRole [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\unusual-volume-of-file-deletion.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\unusual-volume-of-file-deletion.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\unusual-volume-of-file-sharing.yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\unusual-volume-of-file-sharing.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\CloudAppEvents\UpdateStsRefreshToken[Solorigate].yaml
# YAML data stored in MongoDB collection CloudAppEvents_collection: files_parsed_by_nahed\CloudAppEvents\UpdateStsRefreshToken[Solorigate].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceAlertEvents\Events surrounding alert (1).yaml
# YAML data stored in MongoDB collection DeviceAlertEvents_collection: files_parsed_by_nahed\DeviceAlertEvents\Events surrounding alert (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceAlertEvents\Events surrounding alert (3).yaml
# YAML data stored in MongoDB collection DeviceAlertEvents_collection: files_parsed_by_nahed\DeviceAlertEvents\Events surrounding alert (3).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\anomalous-payload-delivered-from-iso-file.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\anomalous-payload-delivered-from-iso-file.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Antivirus detections.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Antivirus detections.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ASR--Rule-Ransomware-triggered.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ASR--Rule-Ransomware-triggered.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ASR-rules-categorized-detection-graph.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ASR-rules-categorized-detection-graph.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\AV Detections with Source.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\AV Detections with Source.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\AV Detections with USB Disk Drive.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\AV Detections with USB Disk Drive.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Baseline Comparison.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Baseline Comparison.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\c2-lookup-from-nonbrowser[Nobelium].yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\c2-lookup-from-nonbrowser[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\c2-lookup-response[Nobelium].yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\c2-lookup-response[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\C2-NamedPipe.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\C2-NamedPipe.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Create account (1).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Create account (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\deimos-component-execution.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\deimos-component-execution.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\detect-cyzfc-activity (4).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\detect-cyzfc-activity (4).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\detect-cyzfc-activity.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\detect-cyzfc-activity.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\DNSPattern [Nobelium].yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\DNSPattern [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Doc attachment with link to download.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Doc attachment with link to download.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Email link + download + SmartScreen warning.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Email link + download + SmartScreen warning.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\EncodedDomainURL [Nobelium].yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\EncodedDomainURL [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardAsrDescriptions.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardAsrDescriptions.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardASRStats (1).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardASRStats (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardASRStats (2).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardASRStats (2).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardASRStats.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardASRStats.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess (1).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess (2).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess (2).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess (3).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess (3).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardBlockOfficeChildProcess.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardControlledFolderAccess (1).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardControlledFolderAccess (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardControlledFolderAccess (2).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardControlledFolderAccess (2).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardControlledFolderAccess.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardControlledFolderAccess.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardNetworkProtectionEvents.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardNetworkProtectionEvents.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardStats (1).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardStats (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ExploitGuardStats.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ExploitGuardStats.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\File footprint.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\File footprint.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Files copied to USB drives.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Files copied to USB drives.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\insider-threat-detection-queries (12).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\insider-threat-detection-queries (12).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\insider-threat-detection-queries (19).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\insider-threat-detection-queries (19).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\insider-threat-detection-queries (4).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\insider-threat-detection-queries (4).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\KNOTWEED-FileHashIOCsJuly2022.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\KNOTWEED-FileHashIOCsJuly2022.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\LemonDuck-registration-function.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\LemonDuck-registration-function.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\LocalAdminGroupChanges.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\LocalAdminGroupChanges.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Map external devices (1).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Map external devices (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Map external devices.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Map external devices.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Network footprint (2).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Network footprint (2).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Open email link.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Open email link.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Pivot from detections to related downloads.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Pivot from detections to related downloads.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Possible File Copy to USB Drive.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Possible File Copy to USB Drive.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\PowershellCommand - uncommon commands on machine.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\PowershellCommand - uncommon commands on machine.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\PowershellCommand footprint.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\PowershellCommand footprint.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\PUA ThreatName per Computer.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\PUA ThreatName per Computer.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\scheduled task creation.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\scheduled task creation.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\ServiceAccountsPerformingRemotePS.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\ServiceAccountsPerformingRemotePS.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\SmartScreen app block ignored by user.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\SmartScreen app block ignored by user.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\SmartScreen URL block ignored by user.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\SmartScreen URL block ignored by user.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\snip3-detectsanboxie-function-call.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\snip3-detectsanboxie-function-call.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\SuspiciousUrlClicked.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\SuspiciousUrlClicked.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\System Guard Security Level Baseline.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\System Guard Security Level Baseline.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\System Guard Security Level Drop.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\System Guard Security Level Drop.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\User navigation to redirected URL.yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\User navigation to redirected URL.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceEvents\Windows filtering events (Firewall).yaml
# YAML data stored in MongoDB collection DeviceEvents_collection: files_parsed_by_nahed\DeviceEvents\Windows filtering events (Firewall).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\compromised nvidia certificates[Lapsus$].yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\compromised nvidia certificates[Lapsus$].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\compromised-certificate[Nobelium].yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\compromised-certificate[Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\locate-files-possibly-signed-by-fraudulent-ecc-certificates.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\locate-files-possibly-signed-by-fraudulent-ecc-certificates.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Action1_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Action1_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AeroAdmin_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AeroAdmin_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Ammyy_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Ammyy_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AnyDesk_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AnyDesk_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AnyViewer_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AnyViewer_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Atera_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Atera_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AweSun_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_AweSun_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_BarracudaRMM_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_BarracudaRMM_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_BeyondTrust_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_BeyondTrust_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ConnectWise_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ConnectWise_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DameWare_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DameWare_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DattoRMM_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DattoRMM_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DesktopNow_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DesktopNow_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DistantDesktop_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DistantDesktop_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DWService_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_DWService_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_FleetDeck_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_FleetDeck_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_GetScreen_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_GetScreen_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_IperiusRemote_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_IperiusRemote_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ISLOnline_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ISLOnline_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Kaseya_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Kaseya_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Level_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Level_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_LiteManager_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_LiteManager_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_LogMeIn_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_LogMeIn_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_MeshCentral_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_MeshCentral_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_MSP360_CloudBerry_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_MSP360_CloudBerry_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_NAble_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_NAble_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Naverisk_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Naverisk_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_NetSupport_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_NetSupport_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_NinjaRMM_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_NinjaRMM_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_OptiTune_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_OptiTune_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Panorama9_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Panorama9_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_parsec.app_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_parsec.app_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_PcVisit_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_PcVisit_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_PDQ_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_PDQ_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Pulseway_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Pulseway_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_RealVNC_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_RealVNC_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_RemotePC_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_RemotePC_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_RemoteUtilities_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_RemoteUtilities_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ScreenMeet_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ScreenMeet_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ServerEye_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ServerEye_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ShowMyPC_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ShowMyPC_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_SimpleHelp_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_SimpleHelp_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Splashtop_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_Splashtop_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_SupRemo_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_SupRemo_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_SyncroMSP_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_SyncroMSP_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_TacticalRMM_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_TacticalRMM_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_TeamViewer_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_TeamViewer_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_TightVNC_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_TightVNC_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_UltraViewer_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_UltraViewer_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_XMReality_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_XMReality_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ZohoAssist_filesig.yaml
# YAML data stored in MongoDB collection DeviceFileCertificateInfo_collection: files_parsed_by_nahed\DeviceFileCertificateInfo\rmm_ZohoAssist_filesig.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceFileEvents\Abuse.ch Recent Threat Feed (1).yaml
# ...
# Storing YAML file in MongoDB: files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilitiesKB\fireeye-red-team-tools-CVEs [Nobelium].yaml
# YAML data stored in MongoDB collection DeviceTvmSoftwareVulnerabilitiesKB_collection: files_parsed_by_nahed\DeviceTvmSoftwareVulnerabilitiesKB\fireeye-red-team-tools-CVEs [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\Check for Maalware Baazar (abuse.ch) hashes in your mail flow.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\Check for Maalware Baazar (abuse.ch) hashes in your mail flow.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\detect-archive-exfiltration-to-competitor.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\detect-archive-exfiltration-to-competitor.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\devices_with_vuln_and_users_received_payload.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\devices_with_vuln_and_users_received_payload.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\files-from-malicious-sender.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\files-from-malicious-sender.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\IcedId attachments.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\IcedId attachments.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\insider-threat-detection-queries (18).yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\insider-threat-detection-queries (18).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\jar-attachments.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\jar-attachments.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailAttachmentInfo\JNLP-File-Attachment.yaml
# YAML data stored in MongoDB collection EmailAttachmentInfo_collection: files_parsed_by_nahed\EmailAttachmentInfo\JNLP-File-Attachment.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Appspot Phishing Abuse.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Appspot Phishing Abuse.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Bazacall Emails.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Bazacall Emails.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\detect-archive-exfiltration-to-competitor.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\detect-archive-exfiltration-to-competitor.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Email-RemediationAction-List.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Email-RemediationAction-List.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Fake Replies.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Fake Replies.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\IcedId attachments.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\IcedId attachments.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\IcedId email delivery.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\IcedId email delivery.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\identify-potential-missed-phishing-email-campaigns.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\identify-potential-missed-phishing-email-campaigns.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\insider-threat-detection-queries (10).yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\insider-threat-detection-queries (10).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\insider-threat-detection-queries (18).yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\insider-threat-detection-queries (18).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\jar-attachments.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\jar-attachments.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\LemonDuck-email-subjects.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\LemonDuck-email-subjects.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\logon-attempts-after-malicious-email.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\logon-attempts-after-malicious-email.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Phish and Malware received by user vs total amount of email.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Phish and Malware received by user vs total amount of email.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\powershell-activity-after-email-from-malicious-sender.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\powershell-activity-after-email-from-malicious-sender.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\referral-phish-emails.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\referral-phish-emails.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\snip3-aviation-targeting-emails.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\snip3-aviation-targeting-emails.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Suspicious Google Doc Links.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Suspicious Google Doc Links.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\SuspiciousUrlClicked.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\SuspiciousUrlClicked.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Threat actor Phosphorus masquerading as conference organizers (1).yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Threat actor Phosphorus masquerading as conference organizers (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Threat actor Phosphorus masquerading as conference organizers (2).yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Threat actor Phosphorus masquerading as conference organizers (2).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailEvents\Threat actor Phosphorus masquerading as conference organizers.yaml
# YAML data stored in MongoDB collection EmailEvents_collection: files_parsed_by_nahed\EmailEvents\Threat actor Phosphorus masquerading as conference organizers.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailPostDeliveryEvents\Threat actor Phosphorus masquerading as conference organizers (2).yaml
# YAML data stored in MongoDB collection EmailPostDeliveryEvents_collection: files_parsed_by_nahed\EmailPostDeliveryEvents\Threat actor Phosphorus masquerading as conference organizers (2).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\Appspot Phishing Abuse.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\Appspot Phishing Abuse.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\Fake Replies.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\Fake Replies.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\IcedId email delivery.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\IcedId email delivery.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\PhishingEmailUrlRedirector (1).yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\PhishingEmailUrlRedirector (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\PhishingEmailUrlRedirector.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\PhishingEmailUrlRedirector.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\referral-phish-emails.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\referral-phish-emails.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\snip3-aviation-targeting-emails.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\snip3-aviation-targeting-emails.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\StrRAT-Email-Delivery.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\StrRAT-Email-Delivery.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\EmailUrlInfo\Suspicious Google Doc Links.yaml
# YAML data stored in MongoDB collection EmailUrlInfo_collection: files_parsed_by_nahed\EmailUrlInfo\Suspicious Google Doc Links.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityDirectoryEvents\Active Directory Sensitive Group Modifications.yaml
# YAML data stored in MongoDB collection IdentityDirectoryEvents_collection: files_parsed_by_nahed\IdentityDirectoryEvents\Active Directory Sensitive Group Modifications.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityDirectoryEvents\ActiveDirectory_Account_lockout_and_unlocks.yaml
# YAML data stored in MongoDB collection IdentityDirectoryEvents_collection: files_parsed_by_nahed\IdentityDirectoryEvents\ActiveDirectory_Account_lockout_and_unlocks.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityDirectoryEvents\SAM-Name-Changes-CVE-2021-42278.yaml
# YAML data stored in MongoDB collection IdentityDirectoryEvents_collection: files_parsed_by_nahed\IdentityDirectoryEvents\SAM-Name-Changes-CVE-2021-42278.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityInfo\devices_with_vuln_and_users_received_payload.yaml
# YAML data stored in MongoDB collection IdentityInfo_collection: files_parsed_by_nahed\IdentityInfo\devices_with_vuln_and_users_received_payload.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityInfo\LocalAdminGroupChanges.yaml
# YAML data stored in MongoDB collection IdentityInfo_collection: files_parsed_by_nahed\IdentityInfo\LocalAdminGroupChanges.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityInfo\Non_intended_user_logon.yaml
# YAML data stored in MongoDB collection IdentityInfo_collection: files_parsed_by_nahed\IdentityInfo\Non_intended_user_logon.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityInfo\SuspiciousUrlClicked.yaml
# YAML data stored in MongoDB collection IdentityInfo_collection: files_parsed_by_nahed\IdentityInfo\SuspiciousUrlClicked.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityLogonEvents\Detect-Not-Active-AD-User-Accounts.yaml
# YAML data stored in MongoDB collection IdentityLogonEvents_collection: files_parsed_by_nahed\IdentityLogonEvents\Detect-Not-Active-AD-User-Accounts.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityLogonEvents\detect-potential-kerberoast-activities.yaml
# YAML data stored in MongoDB collection IdentityLogonEvents_collection: files_parsed_by_nahed\IdentityLogonEvents\detect-potential-kerberoast-activities.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityLogonEvents\Device Logons from Unknown IPs.yaml
# YAML data stored in MongoDB collection IdentityLogonEvents_collection: files_parsed_by_nahed\IdentityLogonEvents\Device Logons from Unknown IPs.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityLogonEvents\logon-attempts-after-malicious-email.yaml
# YAML data stored in MongoDB collection IdentityLogonEvents_collection: files_parsed_by_nahed\IdentityLogonEvents\logon-attempts-after-malicious-email.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityLogonEvents\Non-local logons with -500 account.yaml
# YAML data stored in MongoDB collection IdentityLogonEvents_collection: files_parsed_by_nahed\IdentityLogonEvents\Non-local logons with -500 account.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\c2-lookup-from-nonbrowser[Nobelium] (1).yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\c2-lookup-from-nonbrowser[Nobelium] (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\c2-lookup-response[Nobelium] (1).yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\c2-lookup-response[Nobelium] (1).yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\DNSPattern [Nobelium].yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\DNSPattern [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\EncodedDomainURL [Nobelium].yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\EncodedDomainURL [Nobelium].yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\MultipleLdaps.yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\MultipleLdaps.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\MultipleSensitiveLdaps.yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\MultipleSensitiveLdaps.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\PasswordSearch.yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\PasswordSearch.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\Roasting.yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\Roasting.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\SensitiveLdaps.yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\SensitiveLdaps.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\IdentityQueryEvents\VulnComputers.yaml
# YAML data stored in MongoDB collection IdentityQueryEvents_collection: files_parsed_by_nahed\IdentityQueryEvents\VulnComputers.yaml
# Storing YAML file in MongoDB: files_parsed_by_nahed\SecurityAlert (MDATP)\KNOTWEED-AVDetections.yaml
# YAML data stored in MongoDB collection SecurityAlert (MDATP)_collection: files_parsed_by_nahed\SecurityAlert (MDATP)\KNOTWEED-AVDetections.yaml

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\python312\lib\site-packages (from beautifulsoup4) (2.5)

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 650.2 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 650.2 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 650.2 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 232.0 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 5.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.5 MB 5.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.5 MB 9.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/11.5 MB 13.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.1/11.5 MB 13.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.3/11.5 MB 15.2 MB/s eta 0:00:01
#    ------------------ --------------------- 5.4/11.5 MB 16.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.5 MB 17.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.5 MB 15.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.5 MB 15.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.8/11.5 MB 15.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 14.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 14.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.5 MB 15.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.5 MB 15.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 7.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/15.5 MB 42.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.2/15.5 MB 28.1 MB/s eta 0:00:01
#    ------- -------------------------------- 2.9/15.5 MB 22.9 MB/s eta 0:00:01
#    --------- ------------------------------ 3.7/15.5 MB 21.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.4/15.5 MB 20.2 MB/s eta 0:00:01
#    ------------- -------------------------- 5.3/15.5 MB 19.8 MB/s eta 0:00:01
#    --------------- ------------------------ 6.0/15.5 MB 19.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.7/15.5 MB 18.5 MB/s eta 0:00:01
#    ------------------ --------------------- 7.2/15.5 MB 17.6 MB/s eta 0:00:01
#    -------------------- ------------------- 8.0/15.5 MB 17.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.6/15.5 MB 17.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.6/15.5 MB 16.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.8/15.5 MB 15.2 MB/s eta 0:00:01
#    ------------------------ --------------- 9.5/15.5 MB 15.2 MB/s eta 0:00:01
#    ------------------------- -------------- 9.7/15.5 MB 14.8 MB/s eta 0:00:01
#    -------------------------- ------------- 10.3/15.5 MB 13.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.9/15.5 MB 13.4 MB/s eta 0:00:01
#    ------------------------------ --------- 11.7/15.5 MB 13.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.4/15.5 MB 12.8 MB/s eta 0:00:01
#    --------------------------------- ------ 12.9/15.5 MB 12.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.7/15.5 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.5/15.5 MB 12.4 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.5 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 6.2 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/505.5 kB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 1.4 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ------------------------------------ --- 317.4/345.4 kB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  337.9/345.4 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  337.9/345.4 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.1 pytz-2024.1 tzdata-2024.1

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests) (2024.2.2)

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.18.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.0)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\python312\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\python312\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\python312\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\python312\lib\site-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\python312\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: pycparser in c:\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\python312\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.0 MB 1.7 MB/s eta 0:00:07
#     --------------------------------------- 0.2/10.0 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.0 MB 4.0 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.0 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/10.0 MB 7.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.0 MB 7.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.7/10.0 MB 8.6 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/10.0 MB 9.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.1/10.0 MB 10.0 MB/s eta 0:00:01
#    ------------------- -------------------- 4.9/10.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.6/10.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/10.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------- -------------- 6.5/10.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.8/10.0 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/10.0 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/10.0 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/10.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 7.5 MB/s eta 0:00:00
# Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#    ---------------------------------------- 0.0/460.2 kB ? eta -:--:--
#    --------------------------------------  450.6/460.2 kB 29.4 MB/s eta 0:00:01
#    --------------------------------------  450.6/460.2 kB 29.4 MB/s eta 0:00:01
#    --------------------------------------  450.6/460.2 kB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 460.2/460.2 kB 2.9 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, pysocks, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.18.1 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 wsproto-1.2.0

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL to scrape
url = "https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-schema-tables?view=o365-worldwide"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all tables on the page
    tables = soup.find_all('table')

    # Initialize a list to store all table data
    all_table_data = []

    # Iterate through each table and extract schema information
    for table in tables:
        # Extract column headers (schema)
        headers = [th.text.strip() for th in table.find('thead').find_all('th')]

        # Extract data from each row in the body
        rows = table.find('tbody').find_all('tr')

        # Initialize a list to store table data
        table_data = []

        for row in rows:
            # Extract columns from each row
            columns = row.find_all('td')

            # Extract data from each column
            column_data = [td.text.strip() for td in columns]

            # Create a dictionary representing a row of data
            table_row = {}
            for header, data in zip(headers, column_data):
                table_row[header] = data

            # Append the row to the list
            table_data.append(table_row)

        # Add table data to the main list
        all_table_data.extend(table_data)

    # Create a DataFrame from the collected data
    df = pd.DataFrame(all_table_data)

    # Display the DataFrame
    print(df)
else:
    print(f"Failed to retrieve content. Status code: {response.status_code}")
# Out:
#                                   Table name  \
# 0                        AADSignInEventsBeta
# 1                     AADSpnSignInEventsBeta
# 2                              AlertEvidence
# 3                                  AlertInfo
# 4                           BehaviorEntities
# 5                               BehaviorInfo
# 6                             CloudAppEvents
# 7                               DeviceEvents
# 8                  DeviceFileCertificateInfo
# 9                           DeviceFileEvents
# 10                     DeviceImageLoadEvents
# 11                                DeviceInfo
# 12                         DeviceLogonEvents
# 13                       DeviceNetworkEvents
# 14                         DeviceNetworkInfo
# 15                       DeviceProcessEvents
# 16                      DeviceRegistryEvents
# 17                 DeviceTvmHardwareFirmware
# 18                    DeviceTvmInfoGathering
# 19                  DeviceTvmInfoGatheringKB
# 20    DeviceTvmSecureConfigurationAssessment
# 21  DeviceTvmSecureConfigurationAssessmentKB
# 22             DeviceTvmSoftwareEvidenceBeta
# 23                DeviceTvmSoftwareInventory
# 24          DeviceTvmSoftwareVulnerabilities
# 25        DeviceTvmSoftwareVulnerabilitiesKB
# 26                       EmailAttachmentInfo
# 27                               EmailEvents
# 28                   EmailPostDeliveryEvents
# 29                              EmailUrlInfo
# 30                   IdentityDirectoryEvents
# 31                              IdentityInfo
# 32                       IdentityLogonEvents
# 33                       IdentityQueryEvents
# 34                            UrlClickEvents
#
#                                           Description
# 0   Microsoft Entra interactive and non-interactiv...
# 1   Microsoft Entra service principal and managed ...
# 2   Files, IP addresses, URLs, users, or devices a...
# 3   Alerts from Microsoft Defender for Endpoint, M...
# 4   Behavior data types in Microsoft Defender for ...
# 5       Alerts from Microsoft Defender for Cloud Apps
# 6   Events involving accounts and objects in Offic...
# 7   Multiple event types, including events trigger...
# 8   Certificate information of signed files obtain...
# 9   File creation, modification, and other file sy...
# 10                                 DLL loading events
# 11      Machine information, including OS information
# 12  Sign-ins and other authentication events on de...
# 13              Network connection and related events
# 14  Network properties of devices, including physi...
# 15                Process creation and related events
# 16      Creation and modification of registry entries
# 17  Hardware and firmware information of devices a...
# 18  Defender Vulnerability Management assessment e...
# 19  Metadata for assessment events collected in th...
# 20  Microsoft Defender Vulnerability Management as...
# 21  Knowledge base of various security configurati...
# 22  Evidence info about where a specific software ...
# 23  Inventory of software installed on devices, in...
# 24  Software vulnerabilities found on devices and ...
# 25  Knowledge base of publicly disclosed vulnerabi...
# 26         Information about files attached to emails
# 27  Microsoft 365 email events, including email de...
# 28  Security events that occur post-delivery, afte...
# 29                   Information about URLs on emails
# 30  Events involving an on-premises domain control...
# 31  Account information from various sources, incl...
# 32  Authentication events on Active Directory and ...
# 33  Queries for Active Directory objects, such as ...
# 34  Safe Links clicks from email messages, Teams, ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_table_info(table_url):
    response = requests.get(table_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table name
        table_name = soup.find('h1').text.strip()

        # Find the table on the page
        table = soup.find('table')

        # Extract column headers (schema)
        headers = [th.text.strip() for th in table.find('thead').find_all('th')]

        # Extract data from each row in the body
        rows = table.find('tbody').find_all('tr')

        # Initialize a list to store table data
        table_data = []

        for row in rows:
            # Extract columns from each row
            columns = row.find_all('td')

            # Extract data from each column
            column_data = [td.text.strip() for td in columns]

            # Create a dictionary representing a row of data
            row_data = {'Table name': table_name}
            for header, data in zip(headers, column_data):
                row_data[header] = data

            # Append the row to the list
            table_data.append(row_data)

        return table_data
    else:
        print(f"Failed to retrieve content from {table_url}. Status code: {response.status_code}")
        return None

main_url = "https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-schema-tables?view=o365-worldwide"
response = requests.get(main_url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    table_links = soup.find_all('a', class_='hx_short-link')

    # Initialize lists to store all table data
    all_table_names = []
    all_column_names = []
    all_data_types = []
    all_descriptions = []

    for table_link in table_links:
        table_url = table_link['href']
        table_data = extract_table_info(table_url)

        if table_data:
            for row in table_data:
                all_table_names.append(row['Table name'])
                all_column_names.append(row.get('Column name', ''))
                all_data_types.append(row.get('Data type', ''))
                all_descriptions.append(row.get('Description', ''))

    # Print the collected data
    for table_name, column_name, data_type, description in zip(all_table_names, all_column_names, all_data_types, all_descriptions):
        print(f"Table name: {table_name}, Column name: {column_name}, Data type: {data_type}, Description: {description}")

else:
    print(f"Failed to retrieve content. Status code: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup

def extract_table_content(table_url):
    response = requests.get(table_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table on the page
        table = soup.find('table')

        # Extract column headers (schema)
        headers = [th.text.strip() for th in table.find('thead').find_all('th')]

        # Extract data from each row in the body
        rows = table.find('tbody').find_all('tr')

        # Initialize a list to store table data
        table_data = []

        for row in rows:
            # Extract columns from each row
            columns = row.find_all('td')

            # Extract data from each column
            column_data = [td.text.strip() for td in columns]

            # Create a dictionary representing a row of data
            row_data = {header: data for header, data in zip(headers, column_data)}

            # Append the row to the list
            table_data.append(row_data)

        return table_data
    else:
        print(f"Failed to retrieve content from {table_url}. Status code: {response.status_code}")
        return None

# List of URLs for the 35 tables
table_urls = [
    "https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadsignineventsbeta-table?view=o365-worldwide",
    "https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table?view=o365-worldwide",
    # ... add other URLs here
]

# Iterate through the list of URLs and extract content for each table
for table_url in table_urls:
    table_content = extract_table_content(table_url)

    # Print or store the collected data as needed
    if table_content:
        print(f"Content for {table_url}:")
        for row in table_content:
            print(row)
        print("\n")
# Out:
# Content for https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadsignineventsbeta-table?view=o365-worldwide:
# {'Column name': 'Timestamp', 'Data type': 'datetime', 'Description': 'Date and time when the record was generated'}
# {'Column name': 'Application', 'Data type': 'string', 'Description': 'Application that performed the recorded action'}
# {'Column name': 'ApplicationId', 'Data type': 'string', 'Description': 'Unique identifier for the application'}
# {'Column name': 'LogonType', 'Data type': 'string', 'Description': 'Type of logon session, specifically interactive, remote interactive (RDP), network, batch, and service'}
# {'Column name': 'ErrorCode', 'Data type': 'int', 'Description': 'Contains the error code if a sign-in error occurs. To find a description of a specific error code, visit https://aka.ms/AADsigninsErrorCodes.'}
# {'Column name': 'CorrelationId', 'Data type': 'string', 'Description': 'Unique identifier of the sign-in event'}
# {'Column name': 'SessionId', 'Data type': 'string', 'Description': "Unique number assigned to a user by a website's server for the duration of the visit or session"}
# {'Column name': 'AccountDisplayName', 'Data type': 'string', 'Description': 'Name displayed in the address book entry for the account user. This is usually a combination of the given name, middle initial, and surname of the user.'}
# {'Column name': 'AccountObjectId', 'Data type': 'string', 'Description': 'Unique identifier for the account in Microsoft Entra ID'}
# {'Column name': 'AccountUpn', 'Data type': 'string', 'Description': 'User principal name (UPN) of the account'}
# {'Column name': 'IsExternalUser', 'Data type': 'int', 'Description': 'Indicates if the user that signed in is external. Possible values: -1 (not set), 0 (not external), 1 (external).'}
# {'Column name': 'IsGuestUser', 'Data type': 'boolean', 'Description': 'Indicates whether the user that signed in is a guest in the tenant'}
# {'Column name': 'AlternateSignInName', 'Data type': 'string', 'Description': 'On-premises user principal name (UPN) of the user signing in to Microsoft Entra ID'}
# {'Column name': 'LastPasswordChangeTimestamp', 'Data type': 'datetime', 'Description': 'Date and time when the user that signed in last changed their password'}
# {'Column name': 'ResourceDisplayName', 'Data type': 'string', 'Description': 'Display name of the resource accessed. The display name can contain any character.'}
# {'Column name': 'ResourceId', 'Data type': 'string', 'Description': 'Unique identifier of the resource accessed'}
# {'Column name': 'ResourceTenantId', 'Data type': 'string', 'Description': 'Unique identifier of the tenant of the resource accessed'}
# {'Column name': 'DeviceName', 'Data type': 'string', 'Description': 'Fully qualified domain name (FQDN) of the device'}
# {'Column name': 'AadDeviceId', 'Data type': 'string', 'Description': 'Unique identifier for the device in Microsoft Entra ID'}
# {'Column name': 'OSPlatform', 'Data type': 'string', 'Description': 'Platform of the operating system running on the device. Indicates specific operating systems, including variations within the same family, such as Windows 11, Windows 10, and Windows 7.'}
# {'Column name': 'DeviceTrustType', 'Data type': 'string', 'Description': 'Indicates the trust type of the device that signed in. For managed device scenarios only. Possible values are Workplace, AzureAd, and ServerAd.'}
# {'Column name': 'IsManaged', 'Data type': 'int', 'Description': 'Indicates whether the device that initiated the sign-in is a managed device (1) or not a managed device (0)'}
# {'Column name': 'IsCompliant', 'Data type': 'int', 'Description': 'Indicates whether the device that initiated the sign-in is compliant (1) or non-compliant (0)'}
# {'Column name': 'AuthenticationProcessingDetails', 'Data type': 'string', 'Description': 'Details about the authentication processor'}
# {'Column name': 'AuthenticationRequirement', 'Data type': 'string', 'Description': 'Type of authentication required for the sign-in. Possible values: multiFactorAuthentication (MFA was required) and singleFactorAuthentication (no MFA was required).'}
# {'Column name': 'TokenIssuerType', 'Data type': 'int', 'Description': 'Indicates if the token issuer is Microsoft Entra ID (0) or Active Directory Federation Services (1)'}
# {'Column name': 'RiskLevelAggregated', 'Data type': 'int', 'Description': 'Aggregated risk level during sign-in. Possible values: 0 (aggregated risk level not set), 1 (none), 10 (low), 50 (medium), or 100 (high).'}
# {'Column name': 'RiskDetails', 'Data type': 'int', 'Description': 'Details about the risky state of the user that signed in'}
# {'Column name': 'RiskState', 'Data type': 'int', 'Description': 'Indicates risky user state. Possible values: 0 (none), 1 (confirmed safe), 2 (remediated), 3 (dismissed), 4 (at risk), or 5 (confirmed compromised).'}
# {'Column name': 'UserAgent', 'Data type': 'string', 'Description': 'User agent information from the web browser or other client application'}
# {'Column name': 'ClientAppUsed', 'Data type': 'string', 'Description': 'Indicates the client app used'}
# {'Column name': 'Browser', 'Data type': 'string', 'Description': 'Details about the version of the browser used to sign in'}
# {'Column name': 'ConditionalAccessPolicies', 'Data type': 'string', 'Description': 'Details of the conditional access policies applied to the sign-in event'}
# {'Column name': 'ConditionalAccessStatus', 'Data type': 'int', 'Description': 'Status of the conditional access policies applied to the sign-in. Possible values are 0 (policies applied), 1 (attempt to apply policies failed), or 2 (policies not applied).'}
# {'Column name': 'IPAddress', 'Data type': 'string', 'Description': 'IP address assigned to the device during communication'}
# {'Column name': 'Country', 'Data type': 'string', 'Description': 'Two-letter code indicating the country/region where the client IP address is geolocated'}
# {'Column name': 'State', 'Data type': 'string', 'Description': 'State where the sign-in occurred, if available'}
# {'Column name': 'City', 'Data type': 'string', 'Description': 'City where the account user is located'}
# {'Column name': 'Latitude', 'Data type': 'string', 'Description': 'The north to south coordinates of the sign-in location'}
# {'Column name': 'Longitude', 'Data type': 'string', 'Description': 'The east to west coordinates of the sign-in location'}
# {'Column name': 'NetworkLocationDetails', 'Data type': 'string', 'Description': 'Network location details of the authentication processor of the sign-in event'}
# {'Column name': 'RequestId', 'Data type': 'string', 'Description': 'Unique identifier of the request'}
# {'Column name': 'ReportId', 'Data type': 'string', 'Description': 'Unique identifier for the event'}
#
#
# Content for https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table?view=o365-worldwide:
# {'Column name': 'Timestamp', 'Data type': 'datetime', 'Description': 'Date and time when the record was generated'}
# {'Column name': 'Application', 'Data type': 'string', 'Description': 'Application that performed the recorded action'}
# {'Column name': 'ApplicationId', 'Data type': 'string', 'Description': 'Unique identifier for the application'}
# {'Column name': 'IsManagedIdentity', 'Data type': 'boolean', 'Description': 'Indicates whether the sign-in was initiated by a managed identity'}
# {'Column name': 'ErrorCode', 'Data type': 'int', 'Description': 'Contains the error code if a sign-in error occurs. To find a description of a specific error code, visit https://aka.ms/AADsigninsErrorCodes.'}
# {'Column name': 'CorrelationId', 'Data type': 'string', 'Description': 'Unique identifier of the sign-in event'}
# {'Column name': 'ServicePrincipalName', 'Data type': 'string', 'Description': 'Name of the service principal that initiated the sign-in'}
# {'Column name': 'ServicePrincipalId', 'Data type': 'string', 'Description': 'Unique identifier of the service principal that initiated the sign-in'}
# {'Column name': 'ResourceDisplayName', 'Data type': 'string', 'Description': 'Display name of the resource accessed. The display name can contain any character.'}
# {'Column name': 'ResourceId', 'Data type': 'string', 'Description': 'Unique identifier of the resource accessed'}
# {'Column name': 'ResourceTenantId', 'Data type': 'string', 'Description': 'Unique identifier of the tenant of the resource accessed'}
# {'Column name': 'IPAddress', 'Data type': 'string', 'Description': 'IP address assigned to the endpoint and used during related network communications'}
# {'Column name': 'Country', 'Data type': 'string', 'Description': 'Two-letter code indicating the country where the client IP address is geolocated'}
# {'Column name': 'State', 'Data type': 'string', 'Description': 'State where the sign-in occurred, if available'}
# {'Column name': 'City', 'Data type': 'string', 'Description': 'City where the account user is located'}
# {'Column name': 'Latitude', 'Data type': 'string', 'Description': 'The north to south coordinates of the sign-in location'}
# {'Column name': 'Longitude', 'Data type': 'string', 'Description': 'The east to west coordinates of the sign-in location'}
# {'Column name': 'RequestId', 'Data type': 'string', 'Description': 'Unique identifier of the request'}
# {'Column name': 'ReportId', 'Data type': 'string', 'Description': 'Unique identifier for the event'}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_table_content(table_url):
    response = requests.get(table_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table on the page
        table = soup.find('table')

        # Extract column headers (schema)
        headers = [th.text.strip() for th in table.find('thead').find_all('th')]

        # Extract data from each row in the body
        rows = table.find('tbody').find_all('tr')

        # Initialize a list to store table data
        table_data = []

        for row in rows:
            # Extract columns from each row
            columns = row.find_all('td')

            # Extract data from each column
            column_data = [td.text.strip() for td in columns]

            # Create a dictionary representing a row of data
            row_data = {header: data for header, data in zip(headers, column_data)}

            # Append the row to the list
            table_data.append(row_data)

        # Convert the list of dictionaries to a Pandas DataFrame
        df = pd.DataFrame(table_data)
        return df
    else:
        print(f"Failed to retrieve content from {table_url}. Status code: {response.status_code}")
        return None

# List of URLs for the 35 tables
table_urls = [
    "https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadsignineventsbeta-table?view=o365-worldwide",
    "https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table?view=o365-worldwide",
    "learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table",
]

# Initialize an empty DataFrame to store the combined data
combined_df = pd.DataFrame()

# Iterate through the list of URLs and extract content for each table
for table_url in table_urls:
    table_content = extract_table_content(table_url)

    # Print or store the collected data as needed
    if table_content is not None:
        print(f"Content for {table_url}:")
        print(table_content)
        print("\n")

        # Concatenate the current table's data to the combined DataFrame
        combined_df = pd.concat([combined_df, table_content], ignore_index=True)

# Print the combined DataFrame
print("Combined DataFrame:")
print(combined_df)
# Out:
# Content for https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadsignineventsbeta-table?view=o365-worldwide:
#                         Column name Data type  \
# 0                         Timestamp  datetime
# 1                       Application    string
# 2                     ApplicationId    string
# 3                         LogonType    string
# 4                         ErrorCode       int
# 5                     CorrelationId    string
# 6                         SessionId    string
# 7                AccountDisplayName    string
# 8                   AccountObjectId    string
# 9                        AccountUpn    string
# 10                   IsExternalUser       int
# 11                      IsGuestUser   boolean
# 12              AlternateSignInName    string
# 13      LastPasswordChangeTimestamp  datetime
# 14              ResourceDisplayName    string
# 15                       ResourceId    string
# 16                 ResourceTenantId    string
# 17                       DeviceName    string
# 18                      AadDeviceId    string
# 19                       OSPlatform    string
# 20                  DeviceTrustType    string
# 21                        IsManaged       int
# 22                      IsCompliant       int
# 23  AuthenticationProcessingDetails    string
# 24        AuthenticationRequirement    string
# 25                  TokenIssuerType       int
# 26              RiskLevelAggregated       int
# 27                      RiskDetails       int
# 28                        RiskState       int
# 29                        UserAgent    string
# 30                    ClientAppUsed    string
# 31                          Browser    string
# 32        ConditionalAccessPolicies    string
# 33          ConditionalAccessStatus       int
# 34                        IPAddress    string
# 35                          Country    string
# 36                            State    string
# 37                             City    string
# 38                         Latitude    string
# 39                        Longitude    string
# 40           NetworkLocationDetails    string
# 41                        RequestId    string
# 42                         ReportId    string
#
#                                           Description
# 0         Date and time when the record was generated
# 1      Application that performed the recorded action
# 2               Unique identifier for the application
# 3   Type of logon session, specifically interactiv...
# 4   Contains the error code if a sign-in error occ...
# 5              Unique identifier of the sign-in event
# 6   Unique number assigned to a user by a website'...
# 7   Name displayed in the address book entry for t...
# 8   Unique identifier for the account in Microsoft...
# 9            User principal name (UPN) of the account
# 10  Indicates if the user that signed in is extern...
# 11  Indicates whether the user that signed in is a...
# 12  On-premises user principal name (UPN) of the u...
# 13  Date and time when the user that signed in las...
# 14  Display name of the resource accessed. The dis...
# 15         Unique identifier of the resource accessed
# 16  Unique identifier of the tenant of the resourc...
# 17   Fully qualified domain name (FQDN) of the device
# 18  Unique identifier for the device in Microsoft ...
# 19  Platform of the operating system running on th...
# 20  Indicates the trust type of the device that si...
# 21  Indicates whether the device that initiated th...
# 22  Indicates whether the device that initiated th...
# 23         Details about the authentication processor
# 24  Type of authentication required for the sign-i...
# 25  Indicates if the token issuer is Microsoft Ent...
# 26  Aggregated risk level during sign-in. Possible...
# 27  Details about the risky state of the user that...
# 28  Indicates risky user state. Possible values: 0...
# 29  User agent information from the web browser or...
# 30                      Indicates the client app used
# 31  Details about the version of the browser used ...
# 32  Details of the conditional access policies app...
# 33  Status of the conditional access policies appl...
# 34  IP address assigned to the device during commu...
# 35  Two-letter code indicating the country/region ...
# 36     State where the sign-in occurred, if available
# 37             City where the account user is located
# 38  The north to south coordinates of the sign-in ...
# 39  The east to west coordinates of the sign-in lo...
# 40  Network location details of the authentication...
# 41                   Unique identifier of the request
# 42                    Unique identifier for the event
#
#
# Content for https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table?view=o365-worldwide:
#              Column name Data type  \
# 0              Timestamp  datetime
# 1            Application    string
# 2          ApplicationId    string
# 3      IsManagedIdentity   boolean
# 4              ErrorCode       int
# 5          CorrelationId    string
# 6   ServicePrincipalName    string
# 7     ServicePrincipalId    string
# 8    ResourceDisplayName    string
# 9             ResourceId    string
# 10      ResourceTenantId    string
# 11             IPAddress    string
# 12               Country    string
# 13                 State    string
# 14                  City    string
# 15              Latitude    string
# 16             Longitude    string
# 17             RequestId    string
# 18              ReportId    string
#
#                                           Description
# 0         Date and time when the record was generated
# 1      Application that performed the recorded action
# 2               Unique identifier for the application
# 3   Indicates whether the sign-in was initiated by...
# 4   Contains the error code if a sign-in error occ...
# 5              Unique identifier of the sign-in event
# 6   Name of the service principal that initiated t...
# 7   Unique identifier of the service principal tha...
# 8   Display name of the resource accessed. The dis...
# 9          Unique identifier of the resource accessed
# 10  Unique identifier of the tenant of the resourc...
# 11  IP address assigned to the endpoint and used d...
# 12  Two-letter code indicating the country where t...
# 13     State where the sign-in occurred, if available
# 14             City where the account user is located
# 15  The north to south coordinates of the sign-in ...
# 16  The east to west coordinates of the sign-in lo...
# 17                   Unique identifier of the request
# 18                    Unique identifier for the event
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[30], line 55
#      53 # Iterate through the list of URLs and extract content for each table
#      54 for table_url in table_urls:
# ---> 55     table_content = extract_table_content(table_url)
#      57     # Print or store the collected data as needed
#      58     if table_content is not None:
#
# Cell In[30], line 6, in extract_table_content(table_url)
#       5 def extract_table_content(table_url):
# ----> 6     response = requests.get(table_url)
#       8     if response.status_code == 200:
#       9         soup = BeautifulSoup(response.text, 'html.parser')
#
# File C:\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\Python312\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File C:\Python312\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File C:\Python312\Lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File C:\Python312\Lib\site-packages\requests\models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL 'learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table': No scheme supplied. Perhaps you meant https://learn.microsoft.com/en-us/microsoft-365/security/defender/advanced-hunting-aadspnsignineventsbeta-table?
